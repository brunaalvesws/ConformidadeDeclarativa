# %% [markdown]
# Passo a passo:
# 1. Receber os logs e modelos como na v1
# 2. Converter o log de atividades para o novo formato, trocando a coluna lifecycle por start e end no nome da atividade
# 3. Converter o log de acesso para o mesmo formato do log de atividades, colocando a operação no nome
# 4. Adaptar o modelo declare para que todas as operações obrigatórias e proibidas do modelo de acesso virem regras declare
#
# **Mudei o nome da atividade pra não ter traço e tentei usar Precendence e Response pra andar com a coisa, mas travei naquela questão do id da atividade, porque preciso saber de qual atividade é o acesso**

# %%
from Declare4Py.ProcessModels.DeclareModel import DeclareModel

def check_letters(cell, modelo, acesso, atividade):
    """Verifica quais letras (c, r, u, d) estão presentes na célula, diferenciando maiúsculas e minúsculas."""
    # Letras a serem verificadas
    letters = ['c', 'r', 'u', 'd']
    
    if atividade == 'Ferramenta':
        return modelo
    
    cell = str(cell)  # Garantir que a célula é string
    for letter in letters:
        uppercase_present = letter.upper() in cell
        
        if uppercase_present:
            for d in range(1,2001):  
                if f'{acesso} {letter} {d}\n' not in modelo:
                    modelo += 'activity ' + f'{acesso} {letter} {d}\n'
            for d in range(1,2001):
                modelo += f'Precedence[{atividade} begin {d}, {acesso} {letter} {d}] | | |\n'
                modelo += f'Response[{acesso} {letter} {d}, {atividade} complete {d}] | | |\n'
    
    return modelo
    

def convertModelToRules(modeloAcesso, modeloProcesso):
    declare_model_activities = modeloProcesso.activities
    declare_model_constraints = modeloProcesso.serialized_constraints
    
    novoModelo = ''
    
    for act in declare_model_activities:
        for d in range(1,2001):
            novoModelo += 'activity ' + act + ' begin ' + str(d) + '\n'
            novoModelo += 'activity ' + act + ' complete ' + str(d) +'\n'

    # Criar um novo DataFrame com os resultados
    for col in modeloAcesso.columns:
        for index, value in modeloAcesso[col].items():
            novoModelo = check_letters(value, novoModelo, modeloAcesso.iloc[index,0], col)
            
    for rule in declare_model_constraints:
        if ',' in rule:
            rule1, rule2 = rule.split(',')
            rule2, rule3 = rule2.split(']')
            novoModelo += rule1 + ' begin,' + rule2 + ' begin' + ']' + rule3 + '\n'
        else:
            rule1, rule2 = rule.split(']')
            novoModelo += rule1 + ' begin' + ']' + rule2 + '\n'
    
    declare_model = DeclareModel().parse_from_string(novoModelo)
    declare_model.to_file('modeloRegrasConjunto.decl')
    return declare_model

# %%
import pandas as pd
from Declare4Py.ProcessModels.DeclareModel import DeclareModel
from Declare4Py.D4PyEventLog import D4PyEventLog
import pm4py

def PreProcessData(logProcessoPATH, logAcessoPATH, modeloRecursoPATH, modeloProcessoPATH, modeloAcessoPATH):
    logAcesso = D4PyEventLog(case_name="case:concept:name")
    logAcesso.parse_xes_log(logAcessoPATH)
    logAcessoProcessado = pm4py.convert_to_dataframe(logAcesso.get_log())
    logAcessoProcessado = logAcessoProcessado.sort_values(['case:concept:name', 'concept:instance'])
    modeloRecursoProcessado = pd.read_csv(modeloRecursoPATH, sep=';')
    modeloAcessoProcessado = pd.read_csv(modeloAcessoPATH, sep=';')
    declare_model = DeclareModel().parse_from_file(modeloProcessoPATH)
    event_log = D4PyEventLog(case_name="case:concept:name")
    event_log.parse_xes_log(logProcessoPATH)
    return event_log, logAcessoProcessado, modeloRecursoProcessado, declare_model, modeloAcessoProcessado

# %%
import pm4py

def convertLogs(logProcesso, logAcesso):
    '''
    Converte os logs de processo e acesso em um log único que pode ser submetido a verificação de conformidade 
    por meio da biblioteca Declare4Py 
    '''
    logProcessoCSV = pm4py.convert_to_dataframe(logProcesso.get_log())
    logProcessoCSV = logProcessoCSV.sort_values(['case:concept:name', 'concept:instance'])
    for index, row in logProcessoCSV.iterrows():
        logProcessoCSV.at[index, 'concept:name'] = row['concept:name'] + ' ' + row['lifecycle:transition'] + ' ' + str(row['@@case_index']+1)
    logProcessoCSV.drop('lifecycle:transition', axis=1, inplace=True)
    
    for index, row in logAcesso.iterrows():
        logProcessoCSV.loc[len(logProcessoCSV)] = [(row['concept:tool'] + ' ' + row['concept:operation'].lower()) + ' ' + str(row['@@case_index']+1),row['time:timestamp'], row['concept:resource'], row['concept:instance'], len(logProcessoCSV), row['@@case_index'], row['case:concept:name']]
    logProcessoCSV = logProcessoCSV.sort_values(['case:concept:name', 'concept:instance','time:timestamp'])
    logProcessoCSV.to_csv('LogTesteConjunto.csv', index=False)
    pm4py.write_xes(logProcessoCSV, "LogSinteticoConjuntoOFICIAL.xes")

# %%
def formatViolations(df_violations):
    '''
    Formata as violações encontradas na verificação de conformidade do Declare4Py
    '''
    violacoes = []
    for index, row in df_violations.iterrows():
        for coluna in df_violations.columns:
            if row[coluna] == 1:
                violacoes.append(f"Trace {index} violou {coluna}")
    return violacoes

# %%
from Declare4Py.ProcessMiningTasks.ConformanceChecking.MPDeclareAnalyzer import MPDeclareAnalyzer
from Declare4Py.ProcessMiningTasks.ConformanceChecking.MPDeclareResultsBrowser import MPDeclareResultsBrowser

def CheckProcessConformance(modeloProcesso):
    '''
    Checa conformidade de processo entre o log e o modelo DECLARE com a biblioteca Declare4Py
    Recebe um log de processo (em formato EventLog) e um modelo de processo (em DeclareModel)
    
    '''
    event_log = D4PyEventLog(case_name="case:concept:name")
    event_log.parse_xes_log("LogSinteticoConjuntoOFICIAL.xes")
    
    model_constraints = modeloProcesso.get_decl_model_constraints()

    # print("Model constraints:")
    # print("-----------------")
    # for idx, constr in enumerate(model_constraints):
    #     print(idx, constr)
    basic_checker = MPDeclareAnalyzer(log=event_log, declare_model=modeloProcesso, consider_vacuity=False)
    conf_check_res: MPDeclareResultsBrowser = basic_checker.run()
    violacoes = formatViolations(conf_check_res.get_metric(metric="num_violations"))
    return violacoes

# %%
import pm4py

def CheckResourceConformance(logProcesso, logAcesso, modeloRecurso):
    '''
    Checa conformidade entre o log de acesso, log de processo e o modelo de recurso
    Recebe modelo de recurso e logs em csv
    '''
    
    logProcessoCSV = pm4py.convert_to_dataframe(logProcesso.get_log())
    logProcessoCSV = logProcessoCSV.sort_values(['case:concept:name', 'concept:instance'])
    logProcessoFiltrado = logProcessoCSV[logProcessoCSV["lifecycle:transition"] == "begin"]
    
    violacoes = {}
    violacoes["AcessoRecursoEquipe"] = []
    violacoes["AcessoRecursoErrado"] = []
    violacoes["Atividade"] = []
    violacoes["OperacaoProibida"] = [] 
    violacoes["AcessoObgNaoRealizado"] = [] 
    acessosPermitidos = ['c', 'r', 'u', 'd']
    for index, row in modeloRecurso.iterrows():
        demanda = row['case:concept:name']
        recursos = row['concept:resources'].split(", ")
        atividades = logProcessoFiltrado[logProcessoFiltrado['case:concept:name'] == demanda]
        acessos = logAcesso[logAcesso['case:concept:name'] == demanda]
        for i, atv in atividades.iterrows():
            recursoAtv = atv['concept:resource']
            if recursoAtv not in recursos:
                violacoes["Atividade"].append([atv['concept:name'], demanda, recursoAtv])
            
            acessosAtv = acessos[acessos['concept:instance']== atv['concept:instance']]
            for j, acc in acessosAtv.iterrows():
                if recursoAtv != acc['concept:resource']:
                    violacoes["AcessoRecursoErrado"].append([acc['concept:tool'], demanda, acc['concept:resource'], recursoAtv])
                if acc['concept:resource'] not in recursos:
                    violacoes["AcessoRecursoEquipe"].append([acc['concept:tool'], demanda, acc['concept:resource']])
            
            cell = str(acc['concept:operation'])
            for letter in cell:
                if letter.lower() and letter not in acessosPermitidos:
                    violacoes["OperacaoProibida"].append([atv['concept:name'], demanda, letter, acc['concept:tool']])
                if letter.upper() and letter.lower() not in cell.lower():
                    violacoes["AcessoObgNaoRealizado"].append([atv['concept:name'], demanda, letter, acc['concept:tool']])
    return violacoes

# %%
def formatInconformances(conformanceProcess, conformanceResource, conformanceAcess):
    '''
    Formata as inconformidades encontradas em cada verificação (pode vir a combinar os padrões de anomalias no futuro)
    '''
    print('Violações de fluxo de processo:')
    for violation in conformanceProcess:
        print(violation)
    
    print("Violações de Acesso:")
    for key, violation in conformanceAcess.items():
        if key == "OperacaoProibida":
            for occur in violation:
                print(f'Violação de Acesso na atividade {occur[0]} no trace {occur[1]}, a operação {occur[2]} não era permitida para a ferramenta {occur[3]}')
        if key == "AcessoObgNaoRealizado":
            for occur in violation:
                print(f"Violação de Acesso na atividade {occur[0]} no trace {occur[1]}, os acessos obrigatórios às ferramentas {occur[2]} não foram realizados")
    
    
    print('Violações de Privacidade:')
    for key, violation in conformanceResource.items():
        if key == "Atividade":
            for occur in violation:
                print(f'Violação de Privacidade na atividade {occur[0]} no trace {occur[1]}, o recurso {occur[2]} não faz parte da equipe determinada para realizar a demanda')
        if key == "AcessoRecursoEquipe":
            for occur in violation:
                print(f'Violação de Privacidade no acesso a {occur[0]} no trace {occur[1]}, o recurso {occur[2]} não faz parte da equipe determinada para realizar a demanda')
        if key == "AcessoRecursoErrado":
            for occur in violation:
                print(f'Violação de Privacidade no acesso a {occur[0]} no trace {occur[1]}, o recurso {occur[2]} não era o designado da atividade vinculada e sim o {occur[3]}')

# %%
def MultiperspectiveConformanceAlgorithm(logProcessoPATH, logAcessoPATH, modeloRecursoPATH, modeloProcessoPATH, modeloAcessoPATH):
  '''
  O algoritmo recebe: um log de processo, um log de acesso a dados, um modelo de recurso, um modelo DECLARE de processo e um modelo de acesso a dados
  '''
  logProcesso, logAcesso, modeloRecurso, modeloProcesso, modeloAcesso = PreProcessData(logProcessoPATH, logAcessoPATH, modeloRecursoPATH, modeloProcessoPATH, modeloAcessoPATH)
  modeloAcessoConvertido = convertModelToRules(modeloAcesso, modeloProcesso)
  convertLogs(logProcesso, logAcesso)
  conformanceProcess = CheckProcessConformance(modeloAcessoConvertido)
  conformanceResource = CheckResourceConformance(logProcesso, logAcesso, modeloRecurso)
  return formatInconformances(conformanceProcess, conformanceResource, conformanceAcess)

# %%
MultiperspectiveConformanceAlgorithm('./LogSinteticoProcessoOFICIAL.xes', './LogSinteticoAcessoOFICIAL.xes', './ModeloRecursosOFICIAL.csv', './Modelo_Log_Sintetico_OFICIAL.decl', './ModeloAcessoOFICIAL.csv')
# Out:
# parsing log, completed traces :: 100%|██████████| 2000/2000 [00:17<00:00, 115.20it/s]
# parsing log, completed traces :: 100%|██████████| 2000/2000 [00:06<00:00, 329.69it/s]
# exporting log, completed traces :: 100%|██████████| 2000/2000 [00:14<00:00, 138.96it/s]
# parsing log, completed traces :: 100%|██████████| 2000/2000 [00:16<00:00, 119.19it/s]
# Violações de fluxo de processo:
# Trace 0 violou Precedence[Manutencao de funcionalidade begin 1, Codigo u 1] | | |
# Trace 0 violou Response[Codigo u 1, Manutencao de funcionalidade complete 1] | | |
# Trace 0 violou Response[Requisito u 1, Atualizacao de requisitos funcionais complete 1] | | |
# Trace 0 violou Response[Codigo c 1, Construcao de funcionalidade complete 1] | | |
# Trace 0 violou Precedence[Documentacao de requisitos funcionais begin 1, Gestao u 1] | | |
# Trace 0 violou Response[Gestao u 1, Contagem de ponto de funcao complete 1] | | |
# Trace 1 violou Precedence[Manutencao de funcionalidade begin 2, Codigo u 2] | | |
# Trace 1 violou Response[Codigo u 2, Manutencao de funcionalidade complete 2] | | |
# Trace 1 violou Response[Requisito u 2, Atualizacao de requisitos funcionais complete 2] | | |
# Trace 1 violou Precedence[Documentacao de requisitos funcionais begin 2, Gestao u 2] | | |
# Trace 1 violou Response[Gestao u 2, Contagem de ponto de funcao complete 2] | | |
# Trace 2 violou Response[Requisito u 3, Atualizacao de requisitos funcionais complete 3] | | |
# Trace 2 violou Precedence[Documentacao de requisitos funcionais begin 3, Gestao u 3] | | |
# Trace 2 violou Response[Gestao u 3, Contagem de ponto de funcao complete 3] | | |
# Trace 3 violou Response[Codigo u 4, Manutencao de funcionalidade complete 4] | | |
# Trace 3 violou Precedence[Documentacao de requisitos funcionais begin 4, Gestao u 4] | | |
# Trace 3 violou Response[Gestao u 4, Contagem de ponto de funcao complete 4] | | |
# Trace 3 violou Precedence[Corrigir erro begin 4, Codigo u 4] | | |
# Trace 4 violou Precedence[Manutencao de funcionalidade begin 5, Codigo u 5] | | |
# Trace 4 violou Response[Codigo u 5, Manutencao de funcionalidade complete 5] | | |
# Trace 4 violou Response[Codigo c 5, Construcao de funcionalidade complete 5] | | |
# Trace 4 violou Precedence[Documentacao de requisitos funcionais begin 5, Gestao u 5] | | |
# Trace 4 violou Response[Gestao u 5, Contagem de ponto de funcao complete 5] | | |
# Trace 5 violou Response[Requisito u 6, Atualizacao de requisitos funcionais complete 6] | | |
# Trace 5 violou Precedence[Documentacao de requisitos funcionais begin 6, Gestao u 6] | | |
# Trace 5 violou Response[Gestao u 6, Contagem de ponto de funcao complete 6] | | |
# Trace 6 violou Response[Codigo u 7, Manutencao de funcionalidade complete 7] | | |
# Trace 6 violou Response[Codigo c 7, Construcao de funcionalidade complete 7] | | |
# Trace 6 violou Precedence[Documentacao de requisitos funcionais begin 7, Gestao u 7] | | |
# Trace 6 violou Response[Gestao u 7, Contagem de ponto de funcao complete 7] | | |
# Trace 6 violou Precedence[Corrigir erro begin 7, Codigo u 7] | | |
# Trace 7 violou Response[Codigo u 8, Manutencao de funcionalidade complete 8] | | |
# Trace 7 violou Response[Codigo c 8, Construcao de funcionalidade complete 8] | | |
# Trace 7 violou Precedence[Documentacao de requisitos funcionais begin 8, Gestao u 8] | | |
# Trace 7 violou Response[Gestao u 8, Contagem de ponto de funcao complete 8] | | |
# Trace 7 violou Precedence[Corrigir erro begin 8, Codigo u 8] | | |
# Trace 8 violou Response[Codigo u 9, Manutencao de funcionalidade complete 9] | | |
# Trace 8 violou Response[Requisito u 9, Atualizacao de requisitos funcionais complete 9] | | |
# Trace 8 violou Precedence[Documentacao de requisitos funcionais begin 9, Gestao u 9] | | |
# Trace 8 violou Response[Gestao u 9, Contagem de ponto de funcao complete 9] | | |
# Trace 8 violou Precedence[Corrigir erro begin 9, Codigo u 9] | | |
# Trace 9 violou Response[Codigo u 10, Manutencao de funcionalidade complete 10] | | |
# Trace 9 violou Response[Requisito u 10, Atualizacao de requisitos funcionais complete 10] | | |
# Trace 9 violou Response[Codigo c 10, Construcao de funcionalidade complete 10] | | |
# Trace 9 violou Precedence[Documentacao de requisitos funcionais begin 10, Gestao u 10] | | |
# Trace 9 violou Response[Gestao u 10, Contagem de ponto de funcao complete 10] | | |
# Trace 9 violou Precedence[Corrigir erro begin 10, Codigo u 10] | | |
# Trace 10 violou Precedence[Manutencao de funcionalidade begin 11, Codigo u 11] | | |
# Trace 10 violou Response[Codigo u 11, Manutencao de funcionalidade complete 11] | | |
# Trace 10 violou Response[Requisito u 11, Atualizacao de requisitos funcionais complete 11] | | |
# Trace 10 violou Precedence[Documentacao de requisitos funcionais begin 11, Gestao u 11] | | |
# Trace 10 violou Response[Gestao u 11, Contagem de ponto de funcao complete 11] | | |
# Trace 11 violou Response[Requisito u 12, Atualizacao de requisitos funcionais complete 12] | | |
# Trace 11 violou Response[Codigo c 12, Construcao de funcionalidade complete 12] | | |
# Trace 11 violou Precedence[Documentacao de requisitos funcionais begin 12, Gestao u 12] | | |
# Trace 11 violou Response[Gestao u 12, Contagem de ponto de funcao complete 12] | | |
# Trace 11 violou Precedence[Corrigir erro begin 12, Codigo u 12] | | |
# Trace 11 violou Response[Codigo u 12, Corrigir erro complete 12] | | |
# Trace 12 violou Response[Requisito u 13, Atualizacao de requisitos funcionais complete 13] | | |
# Trace 12 violou Precedence[Documentacao de requisitos funcionais begin 13, Gestao u 13] | | |
# Trace 12 violou Response[Gestao u 13, Contagem de ponto de funcao complete 13] | | |
# Trace 12 violou Precedence[Corrigir erro begin 13, Codigo u 13] | | |
# Trace 12 violou Response[Codigo u 13, Corrigir erro complete 13] | | |
# Trace 13 violou Response[Codigo u 14, Manutencao de funcionalidade complete 14] | | |
# Trace 13 violou Response[Requisito u 14, Atualizacao de requisitos funcionais complete 14] | | |
# Trace 13 violou Precedence[Construcao de funcionalidade begin 14, Codigo c 14] | | |
# Trace 13 violou Precedence[Documentacao de requisitos funcionais begin 14, Gestao u 14] | | |
# Trace 13 violou Response[Gestao u 14, Contagem de ponto de funcao complete 14] | | |
# Trace 13 violou Precedence[Corrigir erro begin 14, Codigo u 14] | | |
# Trace 14 violou Precedence[Manutencao de funcionalidade begin 15, Codigo u 15] | | |
# Trace 14 violou Response[Requisito u 15, Atualizacao de requisitos funcionais complete 15] | | |
# Trace 14 violou Precedence[Documentacao de requisitos funcionais begin 15, Gestao u 15] | | |
# Trace 14 violou Response[Gestao u 15, Contagem de ponto de funcao complete 15] | | |
# Trace 14 violou Response[Codigo u 15, Corrigir erro complete 15] | | |
# Trace 15 violou Precedence[Documentacao de requisitos funcionais begin 16, Gestao u 16] | | |
# Trace 15 violou Response[Gestao u 16, Contagem de ponto de funcao complete 16] | | |
# Trace 16 violou Precedence[Manutencao de funcionalidade begin 17, Codigo u 17] | | |
# Trace 16 violou Response[Requisito u 17, Atualizacao de requisitos funcionais complete 17] | | |
# Trace 16 violou Precedence[Construcao de funcionalidade begin 17, Codigo c 17] | | |
# Trace 16 violou Precedence[Documentacao de requisitos funcionais begin 17, Gestao u 17] | | |
# Trace 16 violou Response[Gestao u 17, Contagem de ponto de funcao complete 17] | | |
# Trace 16 violou Response[Codigo u 17, Corrigir erro complete 17] | | |
# Trace 17 violou Precedence[Manutencao de funcionalidade begin 18, Codigo u 18] | | |
# Trace 17 violou Response[Codigo u 18, Manutencao de funcionalidade complete 18] | | |
# Trace 17 violou Precedence[Documentacao de requisitos funcionais begin 18, Gestao u 18] | | |
# Trace 17 violou Response[Gestao u 18, Contagem de ponto de funcao complete 18] | | |
# Trace 18 violou Precedence[Manutencao de funcionalidade begin 19, Codigo u 19] | | |
# Trace 18 violou Response[Codigo u 19, Manutencao de funcionalidade complete 19] | | |
# Trace 18 violou Precedence[Construcao de funcionalidade begin 19, Codigo c 19] | | |
# Trace 18 violou Precedence[Documentacao de requisitos funcionais begin 19, Gestao u 19] | | |
# Trace 18 violou Response[Gestao u 19, Contagem de ponto de funcao complete 19] | | |
# Trace 19 violou Response[Codigo u 20, Manutencao de funcionalidade complete 20] | | |
# Trace 19 violou Precedence[Documentacao de requisitos funcionais begin 20, Gestao u 20] | | |
# Trace 19 violou Response[Gestao u 20, Contagem de ponto de funcao complete 20] | | |
# Trace 19 violou Precedence[Corrigir erro begin 20, Codigo u 20] | | |
# Trace 20 violou Precedence[Manutencao de funcionalidade begin 21, Codigo u 21] | | |
# Trace 20 violou Response[Codigo u 21, Manutencao de funcionalidade complete 21] | | |
# Trace 20 violou Response[Codigo c 21, Construcao de funcionalidade complete 21] | | |
# Trace 20 violou Precedence[Documentacao de requisitos funcionais begin 21, Gestao u 21] | | |
# Trace 20 violou Response[Gestao u 21, Contagem de ponto de funcao complete 21] | | |
# Trace 21 violou Response[Requisito u 22, Atualizacao de requisitos funcionais complete 22] | | |
# Trace 21 violou Response[Codigo c 22, Construcao de funcionalidade complete 22] | | |
# Trace 21 violou Precedence[Documentacao de requisitos funcionais begin 22, Gestao u 22] | | |
# Trace 21 violou Response[Gestao u 22, Contagem de ponto de funcao complete 22] | | |
# Trace 22 violou Response[Codigo u 23, Manutencao de funcionalidade complete 23] | | |
# Trace 22 violou Precedence[Documentacao de requisitos funcionais begin 23, Gestao u 23] | | |
# Trace 22 violou Response[Gestao u 23, Contagem de ponto de funcao complete 23] | | |
# Trace 22 violou Precedence[Corrigir erro begin 23, Codigo u 23] | | |
# Trace 23 violou Precedence[Manutencao de funcionalidade begin 24, Codigo u 24] | | |
# Trace 23 violou Response[Codigo u 24, Manutencao de funcionalidade complete 24] | | |
# Trace 23 violou Response[Requisito u 24, Atualizacao de requisitos funcionais complete 24] | | |
# Trace 23 violou Precedence[Documentacao de requisitos funcionais begin 24, Gestao u 24] | | |
# Trace 23 violou Response[Gestao u 24, Contagem de ponto de funcao complete 24] | | |
# Trace 24 violou Precedence[Manutencao de funcionalidade begin 25, Codigo u 25] | | |
# Trace 24 violou Response[Codigo u 25, Manutencao de funcionalidade complete 25] | | |
# Trace 24 violou Response[Requisito u 25, Atualizacao de requisitos funcionais complete 25] | | |
# Trace 24 violou Precedence[Documentacao de requisitos funcionais begin 25, Gestao u 25] | | |
# Trace 24 violou Response[Gestao u 25, Contagem de ponto de funcao complete 25] | | |
# Trace 25 violou Response[Codigo u 26, Manutencao de funcionalidade complete 26] | | |
# Trace 25 violou Response[Requisito u 26, Atualizacao de requisitos funcionais complete 26] | | |
# Trace 25 violou Response[Codigo c 26, Construcao de funcionalidade complete 26] | | |
# Trace 25 violou Precedence[Documentacao de requisitos funcionais begin 26, Gestao u 26] | | |
# Trace 25 violou Response[Gestao u 26, Contagem de ponto de funcao complete 26] | | |
# Trace 25 violou Precedence[Corrigir erro begin 26, Codigo u 26] | | |
# Trace 26 violou Response[Codigo u 27, Manutencao de funcionalidade complete 27] | | |
# Trace 26 violou Response[Requisito u 27, Atualizacao de requisitos funcionais complete 27] | | |
# Trace 26 violou Precedence[Documentacao de requisitos funcionais begin 27, Gestao u 27] | | |
# Trace 26 violou Response[Gestao u 27, Contagem de ponto de funcao complete 27] | | |
# Trace 26 violou Precedence[Corrigir erro begin 27, Codigo u 27] | | |
# Trace 27 violou Response[Codigo u 28, Manutencao de funcionalidade complete 28] | | |
# Trace 27 violou Response[Codigo c 28, Construcao de funcionalidade complete 28] | | |
# Trace 27 violou Precedence[Documentacao de requisitos funcionais begin 28, Gestao u 28] | | |
# Trace 27 violou Response[Gestao u 28, Contagem de ponto de funcao complete 28] | | |
# Trace 27 violou Precedence[Corrigir erro begin 28, Codigo u 28] | | |
# Trace 28 violou Response[Requisito u 29, Atualizacao de requisitos funcionais complete 29] | | |
# Trace 28 violou Response[Codigo c 29, Construcao de funcionalidade complete 29] | | |
# Trace 28 violou Precedence[Documentacao de requisitos funcionais begin 29, Gestao u 29] | | |
# Trace 28 violou Response[Gestao u 29, Contagem de ponto de funcao complete 29] | | |
# Trace 29 violou Response[Codigo u 30, Manutencao de funcionalidade complete 30] | | |
# Trace 29 violou Response[Codigo c 30, Construcao de funcionalidade complete 30] | | |
# Trace 29 violou Precedence[Documentacao de requisitos funcionais begin 30, Gestao u 30] | | |
# Trace 29 violou Response[Gestao u 30, Contagem de ponto de funcao complete 30] | | |
# Trace 29 violou Precedence[Corrigir erro begin 30, Codigo u 30] | | |
# Trace 30 violou Precedence[Manutencao de funcionalidade begin 31, Codigo u 31] | | |
# Trace 30 violou Response[Codigo u 31, Manutencao de funcionalidade complete 31] | | |
# Trace 30 violou Precedence[Documentacao de requisitos funcionais begin 31, Gestao u 31] | | |
# Trace 30 violou Response[Gestao u 31, Contagem de ponto de funcao complete 31] | | |
# Trace 31 violou Response[Codigo u 32, Manutencao de funcionalidade complete 32] | | |
# Trace 31 violou Precedence[Documentacao de requisitos funcionais begin 32, Gestao u 32] | | |
# Trace 31 violou Response[Gestao u 32, Contagem de ponto de funcao complete 32] | | |
# Trace 31 violou Precedence[Corrigir erro begin 32, Codigo u 32] | | |
# Trace 32 violou Response[Codigo u 33, Manutencao de funcionalidade complete 33] | | |
# Trace 32 violou Response[Codigo c 33, Construcao de funcionalidade complete 33] | | |
# Trace 32 violou Precedence[Documentacao de requisitos funcionais begin 33, Gestao u 33] | | |
# Trace 32 violou Response[Gestao u 33, Contagem de ponto de funcao complete 33] | | |
# Trace 32 violou Precedence[Corrigir erro begin 33, Codigo u 33] | | |
# Trace 33 violou Response[Codigo u 34, Manutencao de funcionalidade complete 34] | | |
# Trace 33 violou Response[Codigo c 34, Construcao de funcionalidade complete 34] | | |
# Trace 33 violou Precedence[Documentacao de requisitos funcionais begin 34, Gestao u 34] | | |
# Trace 33 violou Response[Gestao u 34, Contagem de ponto de funcao complete 34] | | |
# Trace 33 violou Precedence[Corrigir erro begin 34, Codigo u 34] | | |
# Trace 34 violou Response[Codigo u 35, Manutencao de funcionalidade complete 35] | | |
# Trace 34 violou Response[Codigo c 35, Construcao de funcionalidade complete 35] | | |
# Trace 34 violou Precedence[Documentacao de requisitos funcionais begin 35, Gestao u 35] | | |
# Trace 34 violou Response[Gestao u 35, Contagem de ponto de funcao complete 35] | | |
# Trace 34 violou Precedence[Corrigir erro begin 35, Codigo u 35] | | |
# Trace 35 violou Response[Codigo u 36, Manutencao de funcionalidade complete 36] | | |
# Trace 35 violou Response[Requisito u 36, Atualizacao de requisitos funcionais complete 36] | | |
# Trace 35 violou Precedence[Documentacao de requisitos funcionais begin 36, Gestao u 36] | | |
# Trace 35 violou Response[Gestao u 36, Contagem de ponto de funcao complete 36] | | |
# Trace 35 violou Precedence[Corrigir erro begin 36, Codigo u 36] | | |
# Trace 36 violou Precedence[Manutencao de funcionalidade begin 37, Codigo u 37] | | |
# Trace 36 violou Response[Codigo u 37, Manutencao de funcionalidade complete 37] | | |
# Trace 36 violou Precedence[Documentacao de requisitos funcionais begin 37, Gestao u 37] | | |
# Trace 36 violou Response[Gestao u 37, Contagem de ponto de funcao complete 37] | | |
# Trace 37 violou Precedence[Documentacao de requisitos funcionais begin 38, Gestao u 38] | | |
# Trace 37 violou Response[Gestao u 38, Contagem de ponto de funcao complete 38] | | |
# Trace 38 violou Precedence[Documentacao de requisitos funcionais begin 39, Gestao u 39] | | |
# Trace 38 violou Response[Gestao u 39, Contagem de ponto de funcao complete 39] | | |
# Trace 39 violou Response[Codigo u 40, Manutencao de funcionalidade complete 40] | | |
# Trace 39 violou Precedence[Documentacao de requisitos funcionais begin 40, Gestao u 40] | | |
# Trace 39 violou Response[Gestao u 40, Contagem de ponto de funcao complete 40] | | |
# Trace 39 violou Precedence[Corrigir erro begin 40, Codigo u 40] | | |
# Trace 40 violou Precedence[Documentacao de requisitos funcionais begin 41, Gestao u 41] | | |
# Trace 40 violou Response[Gestao u 41, Contagem de ponto de funcao complete 41] | | |
# Trace 41 violou Response[Codigo u 42, Manutencao de funcionalidade complete 42] | | |
# Trace 41 violou Response[Requisito u 42, Atualizacao de requisitos funcionais complete 42] | | |
# Trace 41 violou Response[Codigo c 42, Construcao de funcionalidade complete 42] | | |
# Trace 41 violou Precedence[Documentacao de requisitos funcionais begin 42, Gestao u 42] | | |
# Trace 41 violou Response[Gestao u 42, Contagem de ponto de funcao complete 42] | | |
# Trace 41 violou Precedence[Corrigir erro begin 42, Codigo u 42] | | |
# Trace 42 violou Response[Codigo u 43, Manutencao de funcionalidade complete 43] | | |
# Trace 42 violou Response[Requisito u 43, Atualizacao de requisitos funcionais complete 43] | | |
# Trace 42 violou Precedence[Documentacao de requisitos funcionais begin 43, Gestao u 43] | | |
# Trace 42 violou Response[Gestao u 43, Contagem de ponto de funcao complete 43] | | |
# Trace 42 violou Precedence[Corrigir erro begin 43, Codigo u 43] | | |
# Trace 43 violou Precedence[Manutencao de funcionalidade begin 44, Codigo u 44] | | |
# Trace 43 violou Response[Codigo u 44, Manutencao de funcionalidade complete 44] | | |
# Trace 43 violou Precedence[Documentacao de requisitos funcionais begin 44, Gestao u 44] | | |
# Trace 43 violou Response[Gestao u 44, Contagem de ponto de funcao complete 44] | | |
# Trace 44 violou Response[Codigo u 45, Manutencao de funcionalidade complete 45] | | |
# Trace 44 violou Response[Requisito u 45, Atualizacao de requisitos funcionais complete 45] | | |
# Trace 44 violou Precedence[Documentacao de requisitos funcionais begin 45, Gestao u 45] | | |
# Trace 44 violou Response[Gestao u 45, Contagem de ponto de funcao complete 45] | | |
# Trace 44 violou Precedence[Corrigir erro begin 45, Codigo u 45] | | |
# Trace 45 violou Response[Codigo c 46, Construcao de funcionalidade complete 46] | | |
# Trace 45 violou Precedence[Documentacao de requisitos funcionais begin 46, Gestao u 46] | | |
# Trace 45 violou Response[Gestao u 46, Contagem de ponto de funcao complete 46] | | |
# Trace 46 violou Precedence[Manutencao de funcionalidade begin 47, Codigo u 47] | | |
# Trace 46 violou Response[Codigo u 47, Manutencao de funcionalidade complete 47] | | |
# Trace 46 violou Response[Codigo c 47, Construcao de funcionalidade complete 47] | | |
# Trace 46 violou Precedence[Documentacao de requisitos funcionais begin 47, Gestao u 47] | | |
# Trace 46 violou Response[Gestao u 47, Contagem de ponto de funcao complete 47] | | |
# Trace 47 violou Precedence[Documentacao de requisitos funcionais begin 48, Gestao u 48] | | |
# Trace 47 violou Response[Gestao u 48, Contagem de ponto de funcao complete 48] | | |
# Trace 48 violou Response[Codigo u 49, Manutencao de funcionalidade complete 49] | | |
# Trace 48 violou Precedence[Documentacao de requisitos funcionais begin 49, Gestao u 49] | | |
# Trace 48 violou Response[Gestao u 49, Contagem de ponto de funcao complete 49] | | |
# Trace 48 violou Precedence[Corrigir erro begin 49, Codigo u 49] | | |
# Trace 49 violou Response[Codigo u 50, Manutencao de funcionalidade complete 50] | | |
# Trace 49 violou Response[Requisito u 50, Atualizacao de requisitos funcionais complete 50] | | |
# Trace 49 violou Response[Codigo c 50, Construcao de funcionalidade complete 50] | | |
# Trace 49 violou Precedence[Documentacao de requisitos funcionais begin 50, Gestao u 50] | | |
# Trace 49 violou Response[Gestao u 50, Contagem de ponto de funcao complete 50] | | |
# Trace 49 violou Precedence[Corrigir erro begin 50, Codigo u 50] | | |
# Trace 50 violou Response[Requisito u 51, Atualizacao de requisitos funcionais complete 51] | | |
# Trace 50 violou Precedence[Documentacao de requisitos funcionais begin 51, Gestao u 51] | | |
# Trace 50 violou Response[Gestao u 51, Contagem de ponto de funcao complete 51] | | |
# Trace 50 violou Precedence[Corrigir erro begin 51, Codigo u 51] | | |
# Trace 50 violou Response[Codigo u 51, Corrigir erro complete 51] | | |
# Trace 51 violou Response[Requisito u 52, Atualizacao de requisitos funcionais complete 52] | | |
# Trace 51 violou Response[Codigo c 52, Construcao de funcionalidade complete 52] | | |
# Trace 51 violou Precedence[Documentacao de requisitos funcionais begin 52, Gestao u 52] | | |
# Trace 51 violou Response[Gestao u 52, Contagem de ponto de funcao complete 52] | | |
# Trace 51 violou Precedence[Corrigir erro begin 52, Codigo u 52] | | |
# Trace 51 violou Response[Codigo u 52, Corrigir erro complete 52] | | |
# Trace 52 violou Response[Requisito u 53, Atualizacao de requisitos funcionais complete 53] | | |
# Trace 52 violou Precedence[Construcao de funcionalidade begin 53, Codigo c 53] | | |
# Trace 52 violou Precedence[Documentacao de requisitos funcionais begin 53, Gestao u 53] | | |
# Trace 52 violou Response[Gestao u 53, Contagem de ponto de funcao complete 53] | | |
# Trace 52 violou Precedence[Corrigir erro begin 53, Codigo u 53] | | |
# Trace 52 violou Response[Codigo u 53, Corrigir erro complete 53] | | |
# Trace 53 violou Response[Requisito u 54, Atualizacao de requisitos funcionais complete 54] | | |
# Trace 53 violou Precedence[Construcao de funcionalidade begin 54, Codigo c 54] | | |
# Trace 53 violou Precedence[Documentacao de requisitos funcionais begin 54, Gestao u 54] | | |
# Trace 53 violou Response[Gestao u 54, Contagem de ponto de funcao complete 54] | | |
# Trace 53 violou Precedence[Corrigir erro begin 54, Codigo u 54] | | |
# Trace 53 violou Response[Codigo u 54, Corrigir erro complete 54] | | |
# Trace 54 violou Precedence[Manutencao de funcionalidade begin 55, Codigo u 55] | | |
# Trace 54 violou Response[Requisito u 55, Atualizacao de requisitos funcionais complete 55] | | |
# Trace 54 violou Response[Codigo c 55, Construcao de funcionalidade complete 55] | | |
# Trace 54 violou Precedence[Documentacao de requisitos funcionais begin 55, Gestao u 55] | | |
# Trace 54 violou Response[Gestao u 55, Contagem de ponto de funcao complete 55] | | |
# Trace 54 violou Response[Codigo u 55, Corrigir erro complete 55] | | |
# Trace 55 violou Precedence[Manutencao de funcionalidade begin 56, Codigo u 56] | | |
# Trace 55 violou Response[Requisito u 56, Atualizacao de requisitos funcionais complete 56] | | |
# Trace 55 violou Precedence[Construcao de funcionalidade begin 56, Codigo c 56] | | |
# Trace 55 violou Precedence[Documentacao de requisitos funcionais begin 56, Gestao u 56] | | |
# Trace 55 violou Response[Gestao u 56, Contagem de ponto de funcao complete 56] | | |
# Trace 55 violou Response[Codigo u 56, Corrigir erro complete 56] | | |
# Trace 56 violou Precedence[Manutencao de funcionalidade begin 57, Codigo u 57] | | |
# Trace 56 violou Response[Requisito u 57, Atualizacao de requisitos funcionais complete 57] | | |
# Trace 56 violou Precedence[Documentacao de requisitos funcionais begin 57, Gestao u 57] | | |
# Trace 56 violou Response[Gestao u 57, Contagem de ponto de funcao complete 57] | | |
# Trace 56 violou Response[Codigo u 57, Corrigir erro complete 57] | | |
# Trace 57 violou Precedence[Manutencao de funcionalidade begin 58, Codigo u 58] | | |
# Trace 57 violou Response[Requisito u 58, Atualizacao de requisitos funcionais complete 58] | | |
# Trace 57 violou Precedence[Documentacao de requisitos funcionais begin 58, Gestao u 58] | | |
# Trace 57 violou Response[Gestao u 58, Contagem de ponto de funcao complete 58] | | |
# Trace 57 violou Response[Codigo u 58, Corrigir erro complete 58] | | |
# Trace 58 violou Precedence[Manutencao de funcionalidade begin 59, Codigo u 59] | | |
# Trace 58 violou Response[Requisito u 59, Atualizacao de requisitos funcionais complete 59] | | |
# Trace 58 violou Precedence[Construcao de funcionalidade begin 59, Codigo c 59] | | |
# Trace 58 violou Precedence[Documentacao de requisitos funcionais begin 59, Gestao u 59] | | |
# Trace 58 violou Response[Gestao u 59, Contagem de ponto de funcao complete 59] | | |
# Trace 58 violou Response[Codigo u 59, Corrigir erro complete 59] | | |
# Trace 59 violou Response[Codigo u 60, Manutencao de funcionalidade complete 60] | | |
# Trace 59 violou Precedence[Documentacao de requisitos funcionais begin 60, Gestao u 60] | | |
# Trace 59 violou Response[Gestao u 60, Contagem de ponto de funcao complete 60] | | |
# Trace 59 violou Precedence[Corrigir erro begin 60, Codigo u 60] | | |
# Trace 60 violou Response[Requisito u 61, Atualizacao de requisitos funcionais complete 61] | | |
# Trace 60 violou Precedence[Documentacao de requisitos funcionais begin 61, Gestao u 61] | | |
# Trace 60 violou Response[Gestao u 61, Contagem de ponto de funcao complete 61] | | |
# Trace 61 violou Precedence[Manutencao de funcionalidade begin 62, Codigo u 62] | | |
# Trace 61 violou Response[Codigo u 62, Manutencao de funcionalidade complete 62] | | |
# Trace 61 violou Precedence[Documentacao de requisitos funcionais begin 62, Gestao u 62] | | |
# Trace 61 violou Response[Gestao u 62, Contagem de ponto de funcao complete 62] | | |
# Trace 62 violou Response[Codigo u 63, Manutencao de funcionalidade complete 63] | | |
# Trace 62 violou Response[Requisito u 63, Atualizacao de requisitos funcionais complete 63] | | |
# Trace 62 violou Response[Codigo c 63, Construcao de funcionalidade complete 63] | | |
# Trace 62 violou Precedence[Documentacao de requisitos funcionais begin 63, Gestao u 63] | | |
# Trace 62 violou Response[Gestao u 63, Contagem de ponto de funcao complete 63] | | |
# Trace 62 violou Precedence[Corrigir erro begin 63, Codigo u 63] | | |
# Trace 63 violou Response[Codigo u 64, Manutencao de funcionalidade complete 64] | | |
# Trace 63 violou Response[Codigo c 64, Construcao de funcionalidade complete 64] | | |
# Trace 63 violou Precedence[Documentacao de requisitos funcionais begin 64, Gestao u 64] | | |
# Trace 63 violou Response[Gestao u 64, Contagem de ponto de funcao complete 64] | | |
# Trace 63 violou Precedence[Corrigir erro begin 64, Codigo u 64] | | |
# Trace 64 violou Response[Codigo u 65, Manutencao de funcionalidade complete 65] | | |
# Trace 64 violou Response[Requisito u 65, Atualizacao de requisitos funcionais complete 65] | | |
# Trace 64 violou Response[Codigo c 65, Construcao de funcionalidade complete 65] | | |
# Trace 64 violou Precedence[Documentacao de requisitos funcionais begin 65, Gestao u 65] | | |
# Trace 64 violou Response[Gestao u 65, Contagem de ponto de funcao complete 65] | | |
# Trace 64 violou Precedence[Corrigir erro begin 65, Codigo u 65] | | |
# Trace 65 violou Precedence[Manutencao de funcionalidade begin 66, Codigo u 66] | | |
# Trace 65 violou Response[Codigo u 66, Manutencao de funcionalidade complete 66] | | |
# Trace 65 violou Precedence[Documentacao de requisitos funcionais begin 66, Gestao u 66] | | |
# Trace 65 violou Response[Gestao u 66, Contagem de ponto de funcao complete 66] | | |
# Trace 66 violou Response[Codigo u 67, Manutencao de funcionalidade complete 67] | | |
# Trace 66 violou Response[Requisito u 67, Atualizacao de requisitos funcionais complete 67] | | |
# Trace 66 violou Precedence[Documentacao de requisitos funcionais begin 67, Gestao u 67] | | |
# Trace 66 violou Response[Gestao u 67, Contagem de ponto de funcao complete 67] | | |
# Trace 66 violou Precedence[Corrigir erro begin 67, Codigo u 67] | | |
# Trace 67 violou Precedence[Manutencao de funcionalidade begin 68, Codigo u 68] | | |
# Trace 67 violou Response[Codigo u 68, Manutencao de funcionalidade complete 68] | | |
# Trace 67 violou Response[Codigo c 68, Construcao de funcionalidade complete 68] | | |
# Trace 67 violou Precedence[Documentacao de requisitos funcionais begin 68, Gestao u 68] | | |
# Trace 67 violou Response[Gestao u 68, Contagem de ponto de funcao complete 68] | | |
# Trace 68 violou Precedence[Documentacao de requisitos funcionais begin 69, Gestao u 69] | | |
# Trace 68 violou Response[Gestao u 69, Contagem de ponto de funcao complete 69] | | |
# Trace 69 violou Precedence[Documentacao de requisitos funcionais begin 70, Gestao u 70] | | |
# Trace 69 violou Response[Gestao u 70, Contagem de ponto de funcao complete 70] | | |
# Trace 70 violou Precedence[Documentacao de requisitos funcionais begin 71, Gestao u 71] | | |
# Trace 70 violou Response[Gestao u 71, Contagem de ponto de funcao complete 71] | | |
# Trace 71 violou Response[Codigo c 72, Construcao de funcionalidade complete 72] | | |
# Trace 71 violou Precedence[Documentacao de requisitos funcionais begin 72, Gestao u 72] | | |
# Trace 71 violou Response[Gestao u 72, Contagem de ponto de funcao complete 72] | | |
# Trace 72 violou Response[Codigo u 73, Manutencao de funcionalidade complete 73] | | |
# Trace 72 violou Response[Requisito u 73, Atualizacao de requisitos funcionais complete 73] | | |
# Trace 72 violou Response[Codigo c 73, Construcao de funcionalidade complete 73] | | |
# Trace 72 violou Precedence[Documentacao de requisitos funcionais begin 73, Gestao u 73] | | |
# Trace 72 violou Response[Gestao u 73, Contagem de ponto de funcao complete 73] | | |
# Trace 72 violou Precedence[Corrigir erro begin 73, Codigo u 73] | | |
# Trace 73 violou Response[Codigo u 74, Manutencao de funcionalidade complete 74] | | |
# Trace 73 violou Response[Requisito u 74, Atualizacao de requisitos funcionais complete 74] | | |
# Trace 73 violou Response[Codigo c 74, Construcao de funcionalidade complete 74] | | |
# Trace 73 violou Precedence[Documentacao de requisitos funcionais begin 74, Gestao u 74] | | |
# Trace 73 violou Response[Gestao u 74, Contagem de ponto de funcao complete 74] | | |
# Trace 73 violou Precedence[Corrigir erro begin 74, Codigo u 74] | | |
# Trace 74 violou Precedence[Manutencao de funcionalidade begin 75, Codigo u 75] | | |
# Trace 74 violou Response[Codigo u 75, Manutencao de funcionalidade complete 75] | | |
# Trace 74 violou Response[Requisito u 75, Atualizacao de requisitos funcionais complete 75] | | |
# Trace 74 violou Precedence[Documentacao de requisitos funcionais begin 75, Gestao u 75] | | |
# Trace 74 violou Response[Gestao u 75, Contagem de ponto de funcao complete 75] | | |
# Trace 75 violou Response[Requisito u 76, Atualizacao de requisitos funcionais complete 76] | | |
# Trace 75 violou Precedence[Documentacao de requisitos funcionais begin 76, Gestao u 76] | | |
# Trace 75 violou Response[Gestao u 76, Contagem de ponto de funcao complete 76] | | |
# Trace 76 violou Precedence[Documentacao de requisitos funcionais begin 77, Gestao u 77] | | |
# Trace 76 violou Response[Gestao u 77, Contagem de ponto de funcao complete 77] | | |
# Trace 77 violou Response[Codigo u 78, Manutencao de funcionalidade complete 78] | | |
# Trace 77 violou Response[Requisito u 78, Atualizacao de requisitos funcionais complete 78] | | |
# Trace 77 violou Precedence[Documentacao de requisitos funcionais begin 78, Gestao u 78] | | |
# Trace 77 violou Response[Gestao u 78, Contagem de ponto de funcao complete 78] | | |
# Trace 77 violou Precedence[Corrigir erro begin 78, Codigo u 78] | | |
# Trace 78 violou Response[Requisito u 79, Atualizacao de requisitos funcionais complete 79] | | |
# Trace 78 violou Response[Codigo c 79, Construcao de funcionalidade complete 79] | | |
# Trace 78 violou Precedence[Documentacao de requisitos funcionais begin 79, Gestao u 79] | | |
# Trace 78 violou Response[Gestao u 79, Contagem de ponto de funcao complete 79] | | |
# Trace 79 violou Response[Codigo c 80, Construcao de funcionalidade complete 80] | | |
# Trace 79 violou Precedence[Documentacao de requisitos funcionais begin 80, Gestao u 80] | | |
# Trace 79 violou Response[Gestao u 80, Contagem de ponto de funcao complete 80] | | |
# Trace 80 violou Precedence[Manutencao de funcionalidade begin 81, Codigo u 81] | | |
# Trace 80 violou Response[Codigo u 81, Manutencao de funcionalidade complete 81] | | |
# Trace 80 violou Precedence[Documentacao de requisitos funcionais begin 81, Gestao u 81] | | |
# Trace 80 violou Response[Gestao u 81, Contagem de ponto de funcao complete 81] | | |
# Trace 81 violou Precedence[Construcao de funcionalidade begin 82, Codigo c 82] | | |
# Trace 81 violou Precedence[Documentacao de requisitos funcionais begin 82, Gestao u 82] | | |
# Trace 81 violou Response[Gestao u 82, Contagem de ponto de funcao complete 82] | | |
# Trace 81 violou Precedence[Corrigir erro begin 82, Codigo u 82] | | |
# Trace 81 violou Response[Codigo u 82, Corrigir erro complete 82] | | |
# Trace 82 violou Precedence[Manutencao de funcionalidade begin 83, Codigo u 83] | | |
# Trace 82 violou Response[Requisito u 83, Atualizacao de requisitos funcionais complete 83] | | |
# Trace 82 violou Precedence[Documentacao de requisitos funcionais begin 83, Gestao u 83] | | |
# Trace 82 violou Response[Gestao u 83, Contagem de ponto de funcao complete 83] | | |
# Trace 82 violou Response[Codigo u 83, Corrigir erro complete 83] | | |
# Trace 83 violou Precedence[Manutencao de funcionalidade begin 84, Codigo u 84] | | |
# Trace 83 violou Response[Requisito u 84, Atualizacao de requisitos funcionais complete 84] | | |
# Trace 83 violou Precedence[Construcao de funcionalidade begin 84, Codigo c 84] | | |
# Trace 83 violou Precedence[Documentacao de requisitos funcionais begin 84, Gestao u 84] | | |
# Trace 83 violou Response[Gestao u 84, Contagem de ponto de funcao complete 84] | | |
# Trace 83 violou Response[Codigo u 84, Corrigir erro complete 84] | | |
# Trace 84 violou Precedence[Manutencao de funcionalidade begin 85, Codigo u 85] | | |
# Trace 84 violou Precedence[Documentacao de requisitos funcionais begin 85, Gestao u 85] | | |
# Trace 84 violou Response[Gestao u 85, Contagem de ponto de funcao complete 85] | | |
# Trace 84 violou Response[Codigo u 85, Corrigir erro complete 85] | | |
# Trace 85 violou Precedence[Manutencao de funcionalidade begin 86, Codigo u 86] | | |
# Trace 85 violou Response[Requisito u 86, Atualizacao de requisitos funcionais complete 86] | | |
# Trace 85 violou Precedence[Documentacao de requisitos funcionais begin 86, Gestao u 86] | | |
# Trace 85 violou Response[Gestao u 86, Contagem de ponto de funcao complete 86] | | |
# Trace 85 violou Response[Codigo u 86, Corrigir erro complete 86] | | |
# Trace 86 violou Precedence[Manutencao de funcionalidade begin 87, Codigo u 87] | | |
# Trace 86 violou Response[Codigo u 87, Manutencao de funcionalidade complete 87] | | |
# Trace 86 violou Precedence[Construcao de funcionalidade begin 87, Codigo c 87] | | |
# Trace 86 violou Precedence[Documentacao de requisitos funcionais begin 87, Gestao u 87] | | |
# Trace 86 violou Response[Gestao u 87, Contagem de ponto de funcao complete 87] | | |
# Trace 87 violou Precedence[Manutencao de funcionalidade begin 88, Codigo u 88] | | |
# Trace 87 violou Response[Codigo c 88, Construcao de funcionalidade complete 88] | | |
# Trace 87 violou Precedence[Documentacao de requisitos funcionais begin 88, Gestao u 88] | | |
# Trace 87 violou Response[Gestao u 88, Contagem de ponto de funcao complete 88] | | |
# Trace 87 violou Response[Codigo u 88, Corrigir erro complete 88] | | |
# Trace 88 violou Response[Codigo u 89, Manutencao de funcionalidade complete 89] | | |
# Trace 88 violou Response[Codigo c 89, Construcao de funcionalidade complete 89] | | |
# Trace 88 violou Precedence[Documentacao de requisitos funcionais begin 89, Gestao u 89] | | |
# Trace 88 violou Response[Gestao u 89, Contagem de ponto de funcao complete 89] | | |
# Trace 88 violou Precedence[Corrigir erro begin 89, Codigo u 89] | | |
# Trace 89 violou Response[Codigo c 90, Construcao de funcionalidade complete 90] | | |
# Trace 89 violou Precedence[Documentacao de requisitos funcionais begin 90, Gestao u 90] | | |
# Trace 89 violou Response[Gestao u 90, Contagem de ponto de funcao complete 90] | | |
# Trace 90 violou Response[Requisito u 91, Atualizacao de requisitos funcionais complete 91] | | |
# Trace 90 violou Response[Codigo c 91, Construcao de funcionalidade complete 91] | | |
# Trace 90 violou Precedence[Documentacao de requisitos funcionais begin 91, Gestao u 91] | | |
# Trace 90 violou Response[Gestao u 91, Contagem de ponto de funcao complete 91] | | |
# Trace 91 violou Response[Codigo u 92, Manutencao de funcionalidade complete 92] | | |
# Trace 91 violou Response[Codigo c 92, Construcao de funcionalidade complete 92] | | |
# Trace 91 violou Precedence[Documentacao de requisitos funcionais begin 92, Gestao u 92] | | |
# Trace 91 violou Response[Gestao u 92, Contagem de ponto de funcao complete 92] | | |
# Trace 91 violou Precedence[Corrigir erro begin 92, Codigo u 92] | | |
# Trace 92 violou Response[Requisito u 93, Atualizacao de requisitos funcionais complete 93] | | |
# Trace 92 violou Precedence[Documentacao de requisitos funcionais begin 93, Gestao u 93] | | |
# Trace 92 violou Response[Gestao u 93, Contagem de ponto de funcao complete 93] | | |
# Trace 93 violou Response[Codigo u 94, Manutencao de funcionalidade complete 94] | | |
# Trace 93 violou Response[Requisito u 94, Atualizacao de requisitos funcionais complete 94] | | |
# Trace 93 violou Precedence[Documentacao de requisitos funcionais begin 94, Gestao u 94] | | |
# Trace 93 violou Response[Gestao u 94, Contagem de ponto de funcao complete 94] | | |
# Trace 93 violou Precedence[Corrigir erro begin 94, Codigo u 94] | | |
# Trace 94 violou Response[Codigo u 95, Manutencao de funcionalidade complete 95] | | |
# Trace 94 violou Response[Requisito u 95, Atualizacao de requisitos funcionais complete 95] | | |
# Trace 94 violou Precedence[Documentacao de requisitos funcionais begin 95, Gestao u 95] | | |
# Trace 94 violou Response[Gestao u 95, Contagem de ponto de funcao complete 95] | | |
# Trace 94 violou Precedence[Corrigir erro begin 95, Codigo u 95] | | |
# Trace 95 violou Response[Requisito u 96, Atualizacao de requisitos funcionais complete 96] | | |
# Trace 95 violou Precedence[Documentacao de requisitos funcionais begin 96, Gestao u 96] | | |
# Trace 95 violou Response[Gestao u 96, Contagem de ponto de funcao complete 96] | | |
# Trace 96 violou Response[Codigo u 97, Manutencao de funcionalidade complete 97] | | |
# Trace 96 violou Precedence[Documentacao de requisitos funcionais begin 97, Gestao u 97] | | |
# Trace 96 violou Response[Gestao u 97, Contagem de ponto de funcao complete 97] | | |
# Trace 96 violou Precedence[Corrigir erro begin 97, Codigo u 97] | | |
# Trace 97 violou Response[Codigo u 98, Manutencao de funcionalidade complete 98] | | |
# Trace 97 violou Response[Requisito u 98, Atualizacao de requisitos funcionais complete 98] | | |
# Trace 97 violou Response[Codigo c 98, Construcao de funcionalidade complete 98] | | |
# Trace 97 violou Precedence[Documentacao de requisitos funcionais begin 98, Gestao u 98] | | |
# Trace 97 violou Response[Gestao u 98, Contagem de ponto de funcao complete 98] | | |
# Trace 97 violou Precedence[Corrigir erro begin 98, Codigo u 98] | | |
# Trace 98 violou Response[Codigo u 99, Manutencao de funcionalidade complete 99] | | |
# Trace 98 violou Response[Codigo c 99, Construcao de funcionalidade complete 99] | | |
# Trace 98 violou Precedence[Documentacao de requisitos funcionais begin 99, Gestao u 99] | | |
# Trace 98 violou Response[Gestao u 99, Contagem de ponto de funcao complete 99] | | |
# Trace 98 violou Precedence[Corrigir erro begin 99, Codigo u 99] | | |
# Trace 99 violou Precedence[Manutencao de funcionalidade begin 100, Codigo u 100] | | |
# Trace 99 violou Response[Codigo u 100, Manutencao de funcionalidade complete 100] | | |
# Trace 99 violou Precedence[Documentacao de requisitos funcionais begin 100, Gestao u 100] | | |
# Trace 99 violou Response[Gestao u 100, Contagem de ponto de funcao complete 100] | | |
# Trace 100 violou Response[Codigo u 101, Manutencao de funcionalidade complete 101] | | |
# Trace 100 violou Response[Requisito u 101, Atualizacao de requisitos funcionais complete 101] | | |
# Trace 100 violou Response[Codigo c 101, Construcao de funcionalidade complete 101] | | |
# Trace 100 violou Precedence[Documentacao de requisitos funcionais begin 101, Gestao u 101] | | |
# Trace 100 violou Response[Gestao u 101, Contagem de ponto de funcao complete 101] | | |
# Trace 100 violou Precedence[Corrigir erro begin 101, Codigo u 101] | | |
# Trace 101 violou Response[Requisito u 102, Atualizacao de requisitos funcionais complete 102] | | |
# Trace 101 violou Precedence[Documentacao de requisitos funcionais begin 102, Gestao u 102] | | |
# Trace 101 violou Response[Gestao u 102, Contagem de ponto de funcao complete 102] | | |
# Trace 102 violou Response[Requisito u 103, Atualizacao de requisitos funcionais complete 103] | | |
# Trace 102 violou Response[Codigo c 103, Construcao de funcionalidade complete 103] | | |
# Trace 102 violou Precedence[Documentacao de requisitos funcionais begin 103, Gestao u 103] | | |
# Trace 102 violou Response[Gestao u 103, Contagem de ponto de funcao complete 103] | | |
# Trace 103 violou Precedence[Manutencao de funcionalidade begin 104, Codigo u 104] | | |
# Trace 103 violou Response[Codigo u 104, Manutencao de funcionalidade complete 104] | | |
# Trace 103 violou Response[Codigo c 104, Construcao de funcionalidade complete 104] | | |
# Trace 103 violou Precedence[Documentacao de requisitos funcionais begin 104, Gestao u 104] | | |
# Trace 103 violou Response[Gestao u 104, Contagem de ponto de funcao complete 104] | | |
# Trace 104 violou Response[Codigo u 105, Manutencao de funcionalidade complete 105] | | |
# Trace 104 violou Response[Codigo c 105, Construcao de funcionalidade complete 105] | | |
# Trace 104 violou Precedence[Documentacao de requisitos funcionais begin 105, Gestao u 105] | | |
# Trace 104 violou Response[Gestao u 105, Contagem de ponto de funcao complete 105] | | |
# Trace 104 violou Precedence[Corrigir erro begin 105, Codigo u 105] | | |
# Trace 105 violou Response[Codigo u 106, Manutencao de funcionalidade complete 106] | | |
# Trace 105 violou Response[Requisito u 106, Atualizacao de requisitos funcionais complete 106] | | |
# Trace 105 violou Precedence[Documentacao de requisitos funcionais begin 106, Gestao u 106] | | |
# Trace 105 violou Response[Gestao u 106, Contagem de ponto de funcao complete 106] | | |
# Trace 105 violou Precedence[Corrigir erro begin 106, Codigo u 106] | | |
# Trace 106 violou Response[Requisito u 107, Atualizacao de requisitos funcionais complete 107] | | |
# Trace 106 violou Precedence[Documentacao de requisitos funcionais begin 107, Gestao u 107] | | |
# Trace 106 violou Response[Gestao u 107, Contagem de ponto de funcao complete 107] | | |
# Trace 107 violou Response[Codigo u 108, Manutencao de funcionalidade complete 108] | | |
# Trace 107 violou Precedence[Documentacao de requisitos funcionais begin 108, Gestao u 108] | | |
# Trace 107 violou Response[Gestao u 108, Contagem de ponto de funcao complete 108] | | |
# Trace 107 violou Precedence[Corrigir erro begin 108, Codigo u 108] | | |
# Trace 108 violou Response[Codigo u 109, Manutencao de funcionalidade complete 109] | | |
# Trace 108 violou Response[Requisito u 109, Atualizacao de requisitos funcionais complete 109] | | |
# Trace 108 violou Response[Codigo c 109, Construcao de funcionalidade complete 109] | | |
# Trace 108 violou Precedence[Documentacao de requisitos funcionais begin 109, Gestao u 109] | | |
# Trace 108 violou Response[Gestao u 109, Contagem de ponto de funcao complete 109] | | |
# Trace 108 violou Precedence[Corrigir erro begin 109, Codigo u 109] | | |
# Trace 109 violou Response[Codigo u 110, Manutencao de funcionalidade complete 110] | | |
# Trace 109 violou Response[Codigo c 110, Construcao de funcionalidade complete 110] | | |
# Trace 109 violou Precedence[Documentacao de requisitos funcionais begin 110, Gestao u 110] | | |
# Trace 109 violou Response[Gestao u 110, Contagem de ponto de funcao complete 110] | | |
# Trace 109 violou Precedence[Corrigir erro begin 110, Codigo u 110] | | |
# Trace 110 violou Precedence[Manutencao de funcionalidade begin 111, Codigo u 111] | | |
# Trace 110 violou Response[Codigo u 111, Manutencao de funcionalidade complete 111] | | |
# Trace 110 violou Response[Requisito u 111, Atualizacao de requisitos funcionais complete 111] | | |
# Trace 110 violou Precedence[Documentacao de requisitos funcionais begin 111, Gestao u 111] | | |
# Trace 110 violou Response[Gestao u 111, Contagem de ponto de funcao complete 111] | | |
# Trace 111 violou Response[Codigo u 112, Manutencao de funcionalidade complete 112] | | |
# Trace 111 violou Response[Requisito u 112, Atualizacao de requisitos funcionais complete 112] | | |
# Trace 111 violou Precedence[Documentacao de requisitos funcionais begin 112, Gestao u 112] | | |
# Trace 111 violou Response[Gestao u 112, Contagem de ponto de funcao complete 112] | | |
# Trace 111 violou Precedence[Corrigir erro begin 112, Codigo u 112] | | |
# Trace 112 violou Response[Codigo u 113, Manutencao de funcionalidade complete 113] | | |
# Trace 112 violou Response[Requisito u 113, Atualizacao de requisitos funcionais complete 113] | | |
# Trace 112 violou Response[Codigo c 113, Construcao de funcionalidade complete 113] | | |
# Trace 112 violou Precedence[Documentacao de requisitos funcionais begin 113, Gestao u 113] | | |
# Trace 112 violou Response[Gestao u 113, Contagem de ponto de funcao complete 113] | | |
# Trace 112 violou Precedence[Corrigir erro begin 113, Codigo u 113] | | |
# Trace 113 violou Response[Codigo c 114, Construcao de funcionalidade complete 114] | | |
# Trace 113 violou Precedence[Documentacao de requisitos funcionais begin 114, Gestao u 114] | | |
# Trace 113 violou Response[Gestao u 114, Contagem de ponto de funcao complete 114] | | |
# Trace 114 violou Response[Codigo u 115, Manutencao de funcionalidade complete 115] | | |
# Trace 114 violou Precedence[Documentacao de requisitos funcionais begin 115, Gestao u 115] | | |
# Trace 114 violou Response[Gestao u 115, Contagem de ponto de funcao complete 115] | | |
# Trace 114 violou Precedence[Corrigir erro begin 115, Codigo u 115] | | |
# Trace 115 violou Response[Codigo u 116, Manutencao de funcionalidade complete 116] | | |
# Trace 115 violou Precedence[Documentacao de requisitos funcionais begin 116, Gestao u 116] | | |
# Trace 115 violou Response[Gestao u 116, Contagem de ponto de funcao complete 116] | | |
# Trace 115 violou Precedence[Corrigir erro begin 116, Codigo u 116] | | |
# Trace 116 violou Precedence[Manutencao de funcionalidade begin 117, Codigo u 117] | | |
# Trace 116 violou Response[Codigo u 117, Manutencao de funcionalidade complete 117] | | |
# Trace 116 violou Precedence[Documentacao de requisitos funcionais begin 117, Gestao u 117] | | |
# Trace 116 violou Response[Gestao u 117, Contagem de ponto de funcao complete 117] | | |
# Trace 117 violou Response[Codigo u 118, Manutencao de funcionalidade complete 118] | | |
# Trace 117 violou Response[Codigo c 118, Construcao de funcionalidade complete 118] | | |
# Trace 117 violou Precedence[Documentacao de requisitos funcionais begin 118, Gestao u 118] | | |
# Trace 117 violou Response[Gestao u 118, Contagem de ponto de funcao complete 118] | | |
# Trace 117 violou Precedence[Corrigir erro begin 118, Codigo u 118] | | |
# Trace 118 violou Response[Codigo u 119, Manutencao de funcionalidade complete 119] | | |
# Trace 118 violou Response[Requisito u 119, Atualizacao de requisitos funcionais complete 119] | | |
# Trace 118 violou Precedence[Documentacao de requisitos funcionais begin 119, Gestao u 119] | | |
# Trace 118 violou Response[Gestao u 119, Contagem de ponto de funcao complete 119] | | |
# Trace 118 violou Precedence[Corrigir erro begin 119, Codigo u 119] | | |
# Trace 119 violou Precedence[Manutencao de funcionalidade begin 120, Codigo u 120] | | |
# Trace 119 violou Response[Codigo u 120, Manutencao de funcionalidade complete 120] | | |
# Trace 119 violou Response[Codigo c 120, Construcao de funcionalidade complete 120] | | |
# Trace 119 violou Precedence[Documentacao de requisitos funcionais begin 120, Gestao u 120] | | |
# Trace 119 violou Response[Gestao u 120, Contagem de ponto de funcao complete 120] | | |
# Trace 120 violou Precedence[Manutencao de funcionalidade begin 121, Codigo u 121] | | |
# Trace 120 violou Response[Requisito u 121, Atualizacao de requisitos funcionais complete 121] | | |
# Trace 120 violou Response[Codigo c 121, Construcao de funcionalidade complete 121] | | |
# Trace 120 violou Precedence[Documentacao de requisitos funcionais begin 121, Gestao u 121] | | |
# ...
# Trace 1964 violou Precedence[Manutencao de funcionalidade begin 1965, Codigo u 1965] | | |
# Trace 1964 violou Response[Requisito u 1965, Atualizacao de requisitos funcionais complete 1965] | | |
# Trace 1964 violou Response[Codigo c 1965, Construcao de funcionalidade complete 1965] | | |
# Trace 1964 violou Precedence[Documentacao de requisitos funcionais begin 1965, Gestao u 1965] | | |
# Trace 1964 violou Response[Gestao u 1965, Corrigir erro complete 1965] | | |
# Trace 1965 violou Precedence[Manutencao de funcionalidade begin 1966, Codigo u 1966] | | |
# Trace 1965 violou Response[Codigo u 1966, Manutencao de funcionalidade complete 1966] | | |
# Trace 1965 violou Response[Requisito u 1966, Atualizacao de requisitos funcionais complete 1966] | | |
# Trace 1965 violou Precedence[Documentacao de requisitos funcionais begin 1966, Gestao u 1966] | | |
# Trace 1965 violou Response[Gestao u 1966, Contagem de ponto de funcao complete 1966] | | |
# Trace 1966 violou Response[Codigo u 1967, Manutencao de funcionalidade complete 1967] | | |
# Trace 1966 violou Precedence[Documentacao de requisitos funcionais begin 1967, Gestao u 1967] | | |
# Trace 1966 violou Response[Gestao u 1967, Gestao da demanda complete 1967] | | |
# Trace 1966 violou Precedence[Corrigir erro begin 1967, Codigo u 1967] | | |
# Trace 1967 violou Precedence[Atualizacao de requisitos funcionais begin 1968, Gestao u 1968] | | |
# Trace 1967 violou Precedence[Construcao de funcionalidade begin 1968, Codigo c 1968] | | |
# Trace 1967 violou Response[Gestao u 1968, Contagem de ponto de funcao complete 1968] | | |
# Trace 1967 violou Response[Codigo u 1968, Corrigir erro complete 1968] | | |
# Trace 1968 violou Precedence[Manutencao de funcionalidade begin 1969, Codigo u 1969] | | |
# Trace 1968 violou Response[Requisito u 1969, Atualizacao de requisitos funcionais complete 1969] | | |
# Trace 1968 violou Response[Codigo c 1969, Construcao de funcionalidade complete 1969] | | |
# Trace 1968 violou Precedence[Documentacao de requisitos funcionais begin 1969, Gestao u 1969] | | |
# Trace 1968 violou Response[Gestao u 1969, Contagem de ponto de funcao complete 1969] | | |
# Trace 1969 violou Precedence[Manutencao de funcionalidade begin 1970, Codigo u 1970] | | |
# Trace 1969 violou Precedence[Construcao de funcionalidade begin 1970, Codigo c 1970] | | |
# Trace 1969 violou Precedence[Documentacao de requisitos funcionais begin 1970, Gestao u 1970] | | |
# Trace 1969 violou Response[Gestao u 1970, Contagem de ponto de funcao complete 1970] | | |
# Trace 1969 violou Response[Codigo u 1970, Corrigir erro complete 1970] | | |
# Trace 1970 violou Response[Requisito u 1971, Atualizacao de requisitos funcionais complete 1971] | | |
# Trace 1970 violou Precedence[Documentacao de requisitos funcionais begin 1971, Gestao u 1971] | | |
# Trace 1970 violou Response[Gestao u 1971, Contagem de ponto de funcao complete 1971] | | |
# Trace 1971 violou Precedence[Documentacao de requisitos funcionais begin 1972, Gestao u 1972] | | |
# Trace 1971 violou Response[Gestao u 1972, Contagem de ponto de funcao complete 1972] | | |
# Trace 1971 violou Precedence[Corrigir erro begin 1972, Codigo u 1972] | | |
# Trace 1971 violou Response[Codigo u 1972, Corrigir erro complete 1972] | | |
# Trace 1972 violou Response[Codigo u 1973, Manutencao de funcionalidade complete 1973] | | |
# Trace 1972 violou Response[Requisito u 1973, Atualizacao de requisitos funcionais complete 1973] | | |
# Trace 1972 violou Precedence[Construcao de funcionalidade begin 1973, Codigo c 1973] | | |
# Trace 1972 violou Precedence[Documentacao de requisitos funcionais begin 1973, Gestao u 1973] | | |
# Trace 1972 violou Response[Gestao u 1973, Contagem de ponto de funcao complete 1973] | | |
# Trace 1973 violou Response[Requisito u 1974, Atualizacao de requisitos funcionais complete 1974] | | |
# Trace 1973 violou Precedence[Documentacao de requisitos funcionais begin 1974, Gestao u 1974] | | |
# Trace 1973 violou Response[Gestao u 1974, Contagem de ponto de funcao complete 1974] | | |
# Trace 1973 violou Precedence[Corrigir erro begin 1974, Codigo u 1974] | | |
# Trace 1973 violou Response[Codigo u 1974, Corrigir erro complete 1974] | | |
# Trace 1974 violou Response[Codigo u 1975, Manutencao de funcionalidade complete 1975] | | |
# Trace 1974 violou Response[Codigo c 1975, Construcao de funcionalidade complete 1975] | | |
# Trace 1974 violou Precedence[Documentacao de requisitos funcionais begin 1975, Gestao u 1975] | | |
# Trace 1974 violou Response[Gestao u 1975, Gestao da demanda complete 1975] | | |
# Trace 1974 violou Precedence[Corrigir erro begin 1975, Codigo u 1975] | | |
# Trace 1975 violou Response[Codigo u 1976, Manutencao de funcionalidade complete 1976] | | |
# Trace 1975 violou Precedence[Documentacao de requisitos funcionais begin 1976, Gestao u 1976] | | |
# Trace 1975 violou Response[Gestao u 1976, Contagem de ponto de funcao complete 1976] | | |
# Trace 1975 violou Precedence[Corrigir erro begin 1976, Codigo u 1976] | | |
# Trace 1976 violou Precedence[Manutencao de funcionalidade begin 1977, Codigo u 1977] | | |
# Trace 1976 violou Response[Codigo u 1977, Manutencao de funcionalidade complete 1977] | | |
# Trace 1976 violou Response[Codigo c 1977, Construcao de funcionalidade complete 1977] | | |
# Trace 1976 violou Precedence[Documentacao de requisitos funcionais begin 1977, Gestao u 1977] | | |
# Trace 1976 violou Response[Gestao u 1977, Contagem de ponto de funcao complete 1977] | | |
# Trace 1977 violou Response[Codigo u 1978, Manutencao de funcionalidade complete 1978] | | |
# Trace 1977 violou Response[Codigo c 1978, Construcao de funcionalidade complete 1978] | | |
# Trace 1977 violou Precedence[Documentacao de requisitos funcionais begin 1978, Gestao u 1978] | | |
# Trace 1977 violou Response[Gestao u 1978, Corrigir erro complete 1978] | | |
# Trace 1977 violou Precedence[Corrigir erro begin 1978, Codigo u 1978] | | |
# Trace 1978 violou Precedence[Manutencao de funcionalidade begin 1979, Codigo u 1979] | | |
# Trace 1978 violou Response[Codigo u 1979, Manutencao de funcionalidade complete 1979] | | |
# Trace 1978 violou Response[Requisito u 1979, Atualizacao de requisitos funcionais complete 1979] | | |
# Trace 1978 violou Response[Codigo c 1979, Construcao de funcionalidade complete 1979] | | |
# Trace 1978 violou Precedence[Documentacao de requisitos funcionais begin 1979, Gestao u 1979] | | |
# Trace 1978 violou Response[Gestao u 1979, Contagem de ponto de funcao complete 1979] | | |
# Trace 1979 violou Precedence[Construcao de funcionalidade begin 1980, Codigo c 1980] | | |
# Trace 1979 violou Response[Codigo c 1980, Construcao de funcionalidade complete 1980] | | |
# Trace 1979 violou Precedence[Documentacao de requisitos funcionais begin 1980, Gestao u 1980] | | |
# Trace 1979 violou Response[Gestao u 1980, Contagem de ponto de funcao complete 1980] | | |
# Trace 1979 violou Response[Codigo u 1980, Corrigir erro complete 1980] | | |
# Trace 1980 violou Precedence[Atualizacao de requisitos funcionais begin 1981, Gestao u 1981] | | |
# Trace 1980 violou Precedence[Atualizacao de requisitos funcionais begin 1981, Requisito u 1981] | | |
# Trace 1980 violou Response[Gestao u 1981, Contagem de ponto de funcao complete 1981] | | |
# Trace 1980 violou Response[Codigo u 1981, Corrigir erro complete 1981] | | |
# Trace 1981 violou Response[Requisito u 1982, Atualizacao de requisitos funcionais complete 1982] | | |
# Trace 1981 violou Precedence[Construcao de funcionalidade begin 1982, Codigo c 1982] | | |
# Trace 1981 violou Precedence[Documentacao de requisitos funcionais begin 1982, Gestao u 1982] | | |
# Trace 1981 violou Response[Gestao u 1982, Contagem de ponto de funcao complete 1982] | | |
# Trace 1981 violou Precedence[Corrigir erro begin 1982, Codigo u 1982] | | |
# Trace 1981 violou Response[Codigo u 1982, Corrigir erro complete 1982] | | |
# Trace 1982 violou Precedence[Atualizacao de requisitos funcionais begin 1983, Gestao u 1983] | | |
# Trace 1982 violou Response[Gestao u 1983, Contagem de ponto de funcao complete 1983] | | |
# Trace 1982 violou Precedence[Corrigir erro begin 1983, Codigo u 1983] | | |
# Trace 1982 violou Response[Codigo u 1983, Corrigir erro complete 1983] | | |
# Trace 1983 violou Precedence[Manutencao de funcionalidade begin 1984, Codigo u 1984] | | |
# Trace 1983 violou Precedence[Atualizacao de requisitos funcionais begin 1984, Gestao u 1984] | | |
# Trace 1983 violou Response[Gestao u 1984, Contagem de ponto de funcao complete 1984] | | |
# Trace 1984 violou Response[Requisito u 1985, Atualizacao de requisitos funcionais complete 1985] | | |
# Trace 1984 violou Precedence[Documentacao de requisitos funcionais begin 1985, Gestao u 1985] | | |
# Trace 1984 violou Response[Gestao u 1985, Gestao da demanda complete 1985] | | |
# Trace 1985 violou Precedence[Manutencao de funcionalidade begin 1986, Codigo u 1986] | | |
# Trace 1985 violou Precedence[Atualizacao de requisitos funcionais begin 1986, Gestao u 1986] | | |
# Trace 1985 violou Response[Gestao u 1986, Gestao da demanda complete 1986] | | |
# Trace 1985 violou Response[Codigo u 1986, Corrigir erro complete 1986] | | |
# Trace 1986 violou Precedence[Documentacao de requisitos funcionais begin 1987, Gestao u 1987] | | |
# Trace 1986 violou Response[Gestao u 1987, Contagem de ponto de funcao complete 1987] | | |
# Trace 1986 violou Precedence[Corrigir erro begin 1987, Codigo u 1987] | | |
# Trace 1987 violou Response[Codigo u 1988, Manutencao de funcionalidade complete 1988] | | |
# Trace 1987 violou Response[Requisito u 1988, Atualizacao de requisitos funcionais complete 1988] | | |
# Trace 1987 violou Precedence[Construcao de funcionalidade begin 1988, Codigo c 1988] | | |
# Trace 1987 violou Precedence[Documentacao de requisitos funcionais begin 1988, Gestao u 1988] | | |
# Trace 1987 violou Response[Gestao u 1988, Corrigir erro complete 1988] | | |
# Trace 1988 violou Precedence[Documentacao de requisitos funcionais begin 1989, Gestao u 1989] | | |
# Trace 1988 violou Response[Gestao u 1989, Gestao da demanda complete 1989] | | |
# Trace 1988 violou Precedence[Corrigir erro begin 1989, Codigo u 1989] | | |
# Trace 1988 violou Response[Codigo u 1989, Corrigir erro complete 1989] | | |
# Trace 1989 violou Response[Codigo u 1990, Manutencao de funcionalidade complete 1990] | | |
# Trace 1989 violou Precedence[Atualizacao de requisitos funcionais begin 1990, Gestao u 1990] | | |
# Trace 1989 violou Precedence[Atualizacao de requisitos funcionais begin 1990, Requisito u 1990] | | |
# Trace 1989 violou Precedence[Construcao de funcionalidade begin 1990, Codigo c 1990] | | |
# Trace 1989 violou Response[Gestao u 1990, Gestao da demanda complete 1990] | | |
# Trace 1989 violou Precedence[Corrigir erro begin 1990, Codigo u 1990] | | |
# Trace 1990 violou Response[Codigo u 1991, Manutencao de funcionalidade complete 1991] | | |
# Trace 1990 violou Precedence[Atualizacao de requisitos funcionais begin 1991, Gestao u 1991] | | |
# Trace 1990 violou Precedence[Construcao de funcionalidade begin 1991, Codigo c 1991] | | |
# Trace 1990 violou Response[Gestao u 1991, Contagem de ponto de funcao complete 1991] | | |
# Trace 1990 violou Precedence[Corrigir erro begin 1991, Codigo u 1991] | | |
# Trace 1991 violou Precedence[Manutencao de funcionalidade begin 1992, Codigo u 1992] | | |
# Trace 1991 violou Response[Codigo u 1992, Manutencao de funcionalidade complete 1992] | | |
# Trace 1991 violou Response[Requisito u 1992, Atualizacao de requisitos funcionais complete 1992] | | |
# Trace 1991 violou Precedence[Documentacao de requisitos funcionais begin 1992, Gestao u 1992] | | |
# Trace 1991 violou Response[Gestao u 1992, Executar teste complete 1992] | | |
# Trace 1992 violou Precedence[Atualizacao de requisitos funcionais begin 1993, Gestao u 1993] | | |
# Trace 1992 violou Response[Requisito u 1993, Atualizacao de requisitos funcionais complete 1993] | | |
# Trace 1992 violou Response[Gestao u 1993, Contagem de ponto de funcao complete 1993] | | |
# Trace 1993 violou Precedence[Manutencao de funcionalidade begin 1994, Codigo u 1994] | | |
# Trace 1993 violou Response[Codigo u 1994, Manutencao de funcionalidade complete 1994] | | |
# Trace 1993 violou Precedence[Atualizacao de requisitos funcionais begin 1994, Requisito u 1994] | | |
# Trace 1993 violou Precedence[Documentacao de requisitos funcionais begin 1994, Gestao u 1994] | | |
# Trace 1993 violou Response[Gestao u 1994, Corrigir erro complete 1994] | | |
# Trace 1994 violou Precedence[Manutencao de funcionalidade begin 1995, Gestao u 1995] | | |
# Trace 1994 violou Response[Requisito u 1995, Atualizacao de requisitos funcionais complete 1995] | | |
# Trace 1994 violou Precedence[Construcao de funcionalidade begin 1995, Codigo c 1995] | | |
# Trace 1994 violou Response[Gestao u 1995, Gestao da demanda complete 1995] | | |
# Trace 1994 violou Precedence[Corrigir erro begin 1995, Codigo u 1995] | | |
# Trace 1994 violou Response[Codigo u 1995, Corrigir erro complete 1995] | | |
# Trace 1995 violou Response[Codigo u 1996, Manutencao de funcionalidade complete 1996] | | |
# Trace 1995 violou Response[Codigo c 1996, Construcao de funcionalidade complete 1996] | | |
# Trace 1995 violou Precedence[Documentacao de requisitos funcionais begin 1996, Gestao u 1996] | | |
# Trace 1995 violou Response[Gestao u 1996, Contagem de ponto de funcao complete 1996] | | |
# Trace 1995 violou Precedence[Corrigir erro begin 1996, Codigo u 1996] | | |
# Trace 1996 violou Precedence[Atualizacao de requisitos funcionais begin 1997, Requisito u 1997] | | |
# Trace 1996 violou Precedence[Construcao de funcionalidade begin 1997, Codigo c 1997] | | |
# Trace 1996 violou Precedence[Documentacao de requisitos funcionais begin 1997, Gestao u 1997] | | |
# Trace 1996 violou Response[Gestao u 1997, Contagem de ponto de funcao complete 1997] | | |
# Trace 1996 violou Precedence[Corrigir erro begin 1997, Codigo u 1997] | | |
# Trace 1997 violou Precedence[Documentacao de requisitos funcionais begin 1998, Gestao u 1998] | | |
# Trace 1997 violou Response[Gestao u 1998, Contagem de ponto de funcao complete 1998] | | |
# Trace 1998 violou Precedence[Manutencao de funcionalidade begin 1999, Codigo u 1999] | | |
# Trace 1998 violou Response[Codigo u 1999, Manutencao de funcionalidade complete 1999] | | |
# Trace 1998 violou Response[Requisito u 1999, Atualizacao de requisitos funcionais complete 1999] | | |
# Trace 1998 violou Precedence[Documentacao de requisitos funcionais begin 1999, Gestao u 1999] | | |
# Trace 1998 violou Response[Gestao u 1999, Contagem de ponto de funcao complete 1999] | | |
# Trace 1999 violou Response[Requisito u 2000, Atualizacao de requisitos funcionais complete 2000] | | |
# Trace 1999 violou Precedence[Construcao de funcionalidade begin 2000, Codigo c 2000] | | |
# Trace 1999 violou Response[Gestao u 2000, Contagem de ponto de funcao complete 2000] | | |
# Trace 1999 violou Precedence[Planejamento de entrega begin 2000, Gestao u 2000] | | |
# Violações de Privacidade:
# Violação de Privacidade no acesso a Gestao no trace Demanda 0001, o recurso re11 não era o designado da atividade vinculada e sim o re1
# Violação de Privacidade no acesso a Requisito no trace Demanda 0001, o recurso re11 não era o designado da atividade vinculada e sim o re1
# Violação de Privacidade no acesso a Requisito no trace Demanda 0001, o recurso re11 não era o designado da atividade vinculada e sim o re1
# Violação de Privacidade no acesso a Requisito no trace Demanda 0001, o recurso re11 não era o designado da atividade vinculada e sim o re1
# Violação de Privacidade no acesso a Codigo no trace Demanda 0001, o recurso re11 não era o designado da atividade vinculada e sim o re1
# Violação de Privacidade no acesso a Requisito no trace Demanda 0001, o recurso re11 não era o designado da atividade vinculada e sim o re1
# Violação de Privacidade no acesso a Gestao no trace Demanda 0001, o recurso re11 não era o designado da atividade vinculada e sim o re1
# Violação de Privacidade na atividade Documentacao de requisitos funcionais no trace Demanda 0001, o recurso re1 não faz parte da equipe determinada para realizar a demanda
