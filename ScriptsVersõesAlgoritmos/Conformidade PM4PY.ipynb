# %%
import pm4py
import pandas as pd

# %%
log = pm4py.read_xes("log_2022_Medio_piores.xes")
log
# Out:
# parsing log, completed traces ::   0%|          | 0/15 [00:00<?, ?it/s]
#       id_demanda_anonimizado        nm_tipodemanda nm_linguagem  \
# 0                   40951248  Manutenção Evolutiva         Java
# 1                   40951248  Manutenção Evolutiva         Java
# 2                   40951248  Manutenção Evolutiva         Java
# 3                   40951248  Manutenção Evolutiva         Java
# 4                   40951248  Manutenção Evolutiva         Java
# ...                      ...                   ...          ...
# 1084                78932088  Manutenção Evolutiva         Java
# 1085                78932088  Manutenção Evolutiva         Java
# 1086                78932088  Manutenção Evolutiva         Java
# 1087                78932088  Manutenção Evolutiva         Java
# 1088                78932088  Manutenção Evolutiva         Java
#
#      nm_cliente_anomizado  vl_pfrealizado                dt_criacao  \
# 0              Cliente 12           86.95 2019-01-14 00:00:00+00:00
# 1              Cliente 12           86.95 2019-01-14 00:00:00+00:00
# 2              Cliente 12           86.95 2019-01-14 00:00:00+00:00
# 3              Cliente 12           86.95 2019-01-14 00:00:00+00:00
# 4              Cliente 12           86.95 2019-01-14 00:00:00+00:00
# ...                   ...             ...                       ...
# 1084          Sem cliente           92.60 2022-10-06 00:00:00+00:00
# 1085          Sem cliente           92.60 2022-10-06 00:00:00+00:00
# 1086          Sem cliente           92.60 2022-10-06 00:00:00+00:00
# 1087          Sem cliente           92.60 2022-10-06 00:00:00+00:00
# 1088          Sem cliente           92.60 2022-10-06 00:00:00+00:00
#
#          dt_inicio_atendimento    dt_entrega_homologacao  \
# 0    2021-10-15 00:00:00+00:00 2022-04-20 00:00:00+00:00
# 1    2021-10-15 00:00:00+00:00 2022-04-20 00:00:00+00:00
# 2    2021-10-15 00:00:00+00:00 2022-04-20 00:00:00+00:00
# 3    2021-10-15 00:00:00+00:00 2022-04-20 00:00:00+00:00
# 4    2021-10-15 00:00:00+00:00 2022-04-20 00:00:00+00:00
# ...                        ...                       ...
# 1084 2022-08-09 00:00:00+00:00 2022-09-19 00:00:00+00:00
# 1085 2022-08-09 00:00:00+00:00 2022-09-19 00:00:00+00:00
# 1086 2022-08-09 00:00:00+00:00 2022-09-19 00:00:00+00:00
# 1087 2022-08-09 00:00:00+00:00 2022-09-19 00:00:00+00:00
# 1088 2022-08-09 00:00:00+00:00 2022-09-19 00:00:00+00:00
#
#                   dt_conclusao  id_tarefa_anonimizado  ...  duracao_por_pf  \
# 0    2022-04-20 00:00:00+00:00               57930192  ...   528634.847614
# 1    2022-04-20 00:00:00+00:00               66116424  ...   528634.847614
# 2    2022-04-20 00:00:00+00:00               66116496  ...   528634.847614
# 3    2022-04-20 00:00:00+00:00               66116520  ...   528634.847614
# 4    2022-04-20 00:00:00+00:00               65277096  ...   528634.847614
# ...                        ...                    ...  ...             ...
# 1084 2022-09-19 00:00:00+00:00               82209096  ...    96103.671706
# 1085 2022-09-19 00:00:00+00:00               78952560  ...    96103.671706
# 1086 2022-09-19 00:00:00+00:00               81182664  ...    96103.671706
# 1087 2022-09-19 00:00:00+00:00               79970160  ...    96103.671706
# 1088 2022-09-19 00:00:00+00:00               80134056  ...    96103.671706
#
#      dt_conclusao_ultima_tarefa  esforco_declarado_por_pf  \
# 0     2022-04-20 00:00:00+00:00              29274.065555
# 1     2022-04-20 00:00:00+00:00              29274.065555
# 2     2022-04-20 00:00:00+00:00              29274.065555
# 3     2022-04-20 00:00:00+00:00              29274.065555
# 4     2022-04-20 00:00:00+00:00              29274.065555
# ...                         ...                       ...
# 1084  2022-09-19 00:00:00+00:00              31075.722259
# 1085  2022-09-19 00:00:00+00:00              31075.722259
# 1086  2022-09-19 00:00:00+00:00              31075.722259
# 1087  2022-09-19 00:00:00+00:00              31075.722259
# 1088  2022-09-19 00:00:00+00:00              31075.722259
#
#        esforco_total_real_por_pf media_atividades_distintas  \
# 0     41 days 00:17:23.358251869                        4.6
# 1     41 days 00:17:23.358251869                        4.6
# 2     41 days 00:17:23.358251869                        4.6
# 3     41 days 00:17:23.358251869                        4.6
# 4     41 days 00:17:23.358251869                        4.6
# ...                          ...                        ...
# 1084   6 days 08:54:56.760259179                        8.0
# 1085   6 days 08:54:56.760259179                        8.0
# 1086   6 days 08:54:56.760259179                        8.0
# 1087   6 days 08:54:56.760259179                        8.0
# 1088   6 days 08:54:56.760259179                        8.0
#
#                                        concept:name            time:timestamp  \
# 0          ATENDIMENTO AOS ACIONAMENTOS DE CLIENTES 2020-11-17 00:00:00+00:00
# 1              ATUALIZACAO DE REQUISITOS FUNCIONAIS 2021-05-07 00:00:00+00:00
# 2              ATUALIZACAO DE REQUISITOS FUNCIONAIS 2021-06-07 00:00:00+00:00
# 3              ATUALIZACAO DE REQUISITOS FUNCIONAIS 2021-06-07 00:00:00+00:00
# 4     VISAO DA SOLUCAO (VS) E VISAO DA DEMANDA (VD) 2021-06-15 00:00:00+00:00
# ...                                             ...                       ...
# 1084          DOCUMENTACAO DE REQUISITOS FUNCIONAIS 2022-09-16 00:00:00+00:00
# 1085                   CONSTRUCAO DE FUNCIONALIDADE 2022-10-06 00:00:00+00:00
# 1086         CORRECAO DE ERROS EM FUNCIONALIDADE(S) 2022-10-08 00:00:00+00:00
# 1087                   MANUTENCAO DE FUNCIONALIDADE 2022-11-07 00:00:00+00:00
# 1088         CORRECAO DE ERROS EM FUNCIONALIDADE(S) 2022-11-07 00:00:00+00:00
#
#      @@index @@case_index case:concept:name
# 0          0            0          40951248
# 1          1            0          40951248
# 2          2            0          40951248
# 3          3            0          40951248
# 4          4            0          40951248
# ...      ...          ...               ...
# 1084    1084           14          78932088
# 1085    1085           14          78932088
# 1086    1086           14          78932088
# 1087    1087           14          78932088
# 1088    1088           14          78932088
#
# [1089 rows x 31 columns]

# %%
declare_model = pm4py.discover_declare(log)
declare_model
# Out:
# {'responded_existence': {('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#    'CONSTRUCAO DE FUNCIONALIDADE'): {'support': 14, 'confidence': 13},
#   ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#    'DOCUMENTACAO DE REQUISITOS FUNCIONAIS'): {'support': 14, 'confidence': 13},
#   ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#    'CONSTRUCAO DE FUNCIONALIDADE'): {'support': 14, 'confidence': 13},
#   ('CONSTRUCAO DE FUNCIONALIDADE',
#    'CORRECAO DE ERROS EM FUNCIONALIDADE(S)'): {'support': 14,
#    'confidence': 12},
#   ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#    'ATUALIZACAO DE REQUISITOS FUNCIONAIS'): {'support': 14, 'confidence': 13},
#   ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#    'MANUTENCAO DE FUNCIONALIDADE'): {'support': 14, 'confidence': 14},
#   ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#    'MANUTENCAO DE FUNCIONALIDADE'): {'support': 14, 'confidence': 14},
#   ('MANUTENCAO DE FUNCIONALIDADE',
#    'CORRECAO DE ERROS EM FUNCIONALIDADE(S)'): {'support': 15,
#    'confidence': 13},
#   ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#    'CONSTRUCAO DE FUNCIONALIDADE'): {'support': 13, 'confidence': 12},
#   ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#    'DOCUMENTACAO DE REQUISITOS FUNCIONAIS'): {'support': 13, 'confidence': 12},
#   ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#    'ATUALIZACAO DE REQUISITOS FUNCIONAIS'): {'support': 13, 'confidence': 13},
#   ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#    'MANUTENCAO DE FUNCIONALIDADE'): {'support': 13, 'confidence': 13},
#   ('CONSTRUCAO DE FUNCIONALIDADE',
#    'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS'): {'support': 14, 'confidence': 12},
#   ('MANUTENCAO DE FUNCIONALIDADE',
#    'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS'): {'support': 15, 'confidence': 13},
#   ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#    'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS'): {'support': 13, 'confidence': 12},
#   ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#    'CORRECAO DE ERROS EM FUNCIONALIDADE(S)'): {'support': 14,
#    'confidence': 13},
#   ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#    'CORRECAO DE ERROS EM FUNCIONALIDADE(S)'): {'support': 14,
#    'confidence': 12},
#   ('CONSTRUCAO DE FUNCIONALIDADE',
#    'DOCUMENTACAO DE REQUISITOS FUNCIONAIS'): {'support': 14, 'confidence': 13},
#   ('CONSTRUCAO DE FUNCIONALIDADE',
#    'ATUALIZACAO DE REQUISITOS FUNCIONAIS'): {'support': 14, 'confidence': 13},
#   ('CONSTRUCAO DE FUNCIONALIDADE',
#    'MANUTENCAO DE FUNCIONALIDADE'): {'support': 14, 'confidence': 14},
#   ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#    'CORRECAO DE ERROS EM FUNCIONALIDADE(S)'): {'support': 13,
#    'confidence': 12},
#   ('MANUTENCAO DE FUNCIONALIDADE',
#    'CONSTRUCAO DE FUNCIONALIDADE'): {'support': 15, 'confidence': 14},
#   ('MANUTENCAO DE FUNCIONALIDADE',
#    'DOCUMENTACAO DE REQUISITOS FUNCIONAIS'): {'support': 15, 'confidence': 14},
#   ('MANUTENCAO DE FUNCIONALIDADE',
#    'ATUALIZACAO DE REQUISITOS FUNCIONAIS'): {'support': 15, 'confidence': 14},
#   ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#    'CONSTRUCAO DE FUNCIONALIDADE'): {'support': 13, 'confidence': 12},
#   ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#    'DOCUMENTACAO DE REQUISITOS FUNCIONAIS'): {'support': 13, 'confidence': 12},
#   ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#    'ATUALIZACAO DE REQUISITOS FUNCIONAIS'): {'support': 13, 'confidence': 13},
#   ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#    'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS'): {'support': 14, 'confidence': 13},
#   ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#    'MANUTENCAO DE FUNCIONALIDADE'): {'support': 13, 'confidence': 13},
#   ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#    'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS'): {'support': 14,
#    'confidence': 12}},
#  'precedence': {('MANUTENCAO DE FUNCIONALIDADE',
#    'CORRECAO DE ERROS EM FUNCIONALIDADE(S)'): {'support': 13,
#    'confidence': 12},
#   ('MANUTENCAO DE FUNCIONALIDADE',
#    'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS'): {'support': 13, 'confidence': 13}},
#  'existence': {'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS': {'support': 15,
#    'confidence': 13},
#   'CONSTRUCAO DE FUNCIONALIDADE': {'support': 15, 'confidence': 14},
#   'DOCUMENTACAO DE REQUISITOS FUNCIONAIS': {'support': 15, 'confidence': 14},
#   'ATUALIZACAO DE REQUISITOS FUNCIONAIS': {'support': 15, 'confidence': 14},
#   'MANUTENCAO DE FUNCIONALIDADE': {'support': 15, 'confidence': 15},
#   'CORRECAO DE ERROS EM FUNCIONALIDADE(S)': {'support': 15, 'confidence': 13}},
#  'response': {('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#    'MANUTENCAO DE FUNCIONALIDADE'): {'support': 14, 'confidence': 14},
#   ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#    'MANUTENCAO DE FUNCIONALIDADE'): {'support': 13, 'confidence': 11}},
#  'absence': {'PLANEJAMENTO DE ENTREGA': {'support': 15, 'confidence': 14},
#   'EXECUTAR TESTES NAO-FUNCIONAIS': {'support': 15, 'confidence': 13},
#   'RELATÓRIO DE AVALIACAO DE TESTES FUNCIONAIS (RLT)': {'support': 15,
#    'confidence': 14},
#   'DOCUMENTACAO DE REQUISITOS NAO FUNCIONAIS (NF)': {'support': 15,
#    'confidence': 14},
#   'DEFINICAO ARQUITETURAL DA SOLUCAO': {'support': 15, 'confidence': 14},
#   'PROTOTIPAR': {'support': 15, 'confidence': 13},
#   'MANUTENCAO DE FLUXOS NO ALM OU GIT': {'support': 15, 'confidence': 14},
#   'ELABORAR CASOS DE TESTES NAO FUNCIONAL': {'support': 15, 'confidence': 14},
#   'ELABORAR MODELO LÓGICO DE DADOS': {'support': 15, 'confidence': 14},
#   'ANÁLISE DE REUSO E ESPECIFICACAO DE NOVOS COMPONENTES': {'support': 15,
#    'confidence': 14},
#   'PARTICIPAR DE EVENTO': {'support': 15, 'confidence': 14},
#   'CRIACAO DE ESTRUTURA INICIAL DE INTEGRACAO CONTÍNUA': {'support': 15,
#    'confidence': 14},
#   'PROPOSTA DE SOLUCAO PROSPECTADA': {'support': 15, 'confidence': 14},
#   'MUDANCA DE INTERFACE (COSMÉTICA)': {'support': 15, 'confidence': 13},
#   'ACOMPANHAMENTO DE MÉTRICAS DO SONAR': {'support': 15, 'confidence': 14},
#   'PROJETO MODELO FÍSICO DE DADOS': {'support': 15, 'confidence': 13},
#   'REEXECUCAO DE APURACAO ESPECIAL COM ALTERACAO DE PARÂMETROS': {'support': 15,
#    'confidence': 14},
#   'ATUALIZACAO DE ARQUIVOS DE DADOS DE CÓDIGO (CODE DATA)': {'support': 15,
#    'confidence': 14},
#   'IDEACAO / RABISCOFRAME': {'support': 15, 'confidence': 14},
#   'PROTOTIPACAO': {'support': 15, 'confidence': 14},
#   'ESPECIFICACAO DE INTEGRACÕES': {'support': 15, 'confidence': 14},
#   'CRIACAO E CONFIGURACAO DOS AMBIENTES DO NOVO SISTEMA/SOLUCA': {'support': 15,
#    'confidence': 14},
#   'ANÁLISE DE RELATOS DE VALIDACAO/HOMOLOGACAO': {'support': 15,
#    'confidence': 13},
#   'CRIACAO, CONFIGURACAO DE USUÁRIO/PERFIL': {'support': 15, 'confidence': 14},
#   'SUPORTE / REPASSE UX': {'support': 15, 'confidence': 14},
#   'ANÁLISE DE PROBLEMA': {'support': 15, 'confidence': 13},
#   'CRIACAO, CONFIGURACAO E ATUALIZACAO DE AMBIENTE': {'support': 15,
#    'confidence': 13},
#   'LEVANTAMENTO DE INFORMACÕES PARA O REGISTRO DE ATIVIDADE DE': {'support': 15,
#    'confidence': 14},
#   'ATUALIZACAO DE PLATAFORMA DO SISTEMA': {'support': 15, 'confidence': 13},
#   'EVENTO DE KICKOFF, INCEPTION OU DESIGN SPRINT': {'support': 15,
#    'confidence': 14},
#   'PLANEJAMENTO DE RELEASE': {'support': 15, 'confidence': 14},
#   'PROSPECCAO DE SOLUCAO': {'support': 15, 'confidence': 14},
#   'ELABORAR MASSA DE DADOS NO AMBIENTE DE HOMOLOGACAO/VALIDACA': {'support': 15,
#    'confidence': 13},
#   'REALIZAR HOMOLOGACAO ASSISTIDA': {'support': 15, 'confidence': 14},
#   'TESTES COM USUÁRIOS': {'support': 15, 'confidence': 14},
#   'COMPONENTE ARQUITETURAL': {'support': 15, 'confidence': 14},
#   'TESTES INTEGRADOS COM OUTRAS EQUIPES': {'support': 15, 'confidence': 14},
#   'CODIFICAR ESTRUTURAS DE PÁGINAS, COMPONENTES ETC': {'support': 15,
#    'confidence': 14},
#   'CASOS DE TESTES AUTOMATIZADOS': {'support': 15, 'confidence': 14},
#   'CRIACAO/MANUTENCAO DE FUNCIONALIDADE': {'support': 15, 'confidence': 13},
#   'ATENDIMENTO AOS ACIONAMENTOS DE CLIENTES': {'support': 15,
#    'confidence': 14},
#   'PROTOTIPACAO COM UI KIT DO DESIGN SYSTEM': {'support': 15,
#    'confidence': 13}},
#  'coexistence': {('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#    'MANUTENCAO DE FUNCIONALIDADE'): {'support': 15, 'confidence': 13},
#   ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#    'ATUALIZACAO DE REQUISITOS FUNCIONAIS'): {'support': 14, 'confidence': 13},
#   ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#    'CORRECAO DE ERROS EM FUNCIONALIDADE(S)'): {'support': 14,
#    'confidence': 12},
#   ('MANUTENCAO DE FUNCIONALIDADE',
#    'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS'): {'support': 15, 'confidence': 13},
#   ('MANUTENCAO DE FUNCIONALIDADE',
#    'ATUALIZACAO DE REQUISITOS FUNCIONAIS'): {'support': 15, 'confidence': 14},
#   ('MANUTENCAO DE FUNCIONALIDADE',
#    'CONSTRUCAO DE FUNCIONALIDADE'): {'support': 15, 'confidence': 14},
#   ('MANUTENCAO DE FUNCIONALIDADE',
#    'CORRECAO DE ERROS EM FUNCIONALIDADE(S)'): {'support': 15,
#    'confidence': 13},
#   ('MANUTENCAO DE FUNCIONALIDADE',
#    'DOCUMENTACAO DE REQUISITOS FUNCIONAIS'): {'support': 15, 'confidence': 14},
#   ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#    'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS'): {'support': 14, 'confidence': 13},
#   ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#    'MANUTENCAO DE FUNCIONALIDADE'): {'support': 15, 'confidence': 14},
#   ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#    'CONSTRUCAO DE FUNCIONALIDADE'): {'support': 15, 'confidence': 13},
#   ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#    'CORRECAO DE ERROS EM FUNCIONALIDADE(S)'): {'support': 14,
#    'confidence': 13},
#   ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#    'DOCUMENTACAO DE REQUISITOS FUNCIONAIS'): {'support': 15, 'confidence': 13},
#   ('CONSTRUCAO DE FUNCIONALIDADE',
#    'MANUTENCAO DE FUNCIONALIDADE'): {'support': 15, 'confidence': 14},
#   ('CONSTRUCAO DE FUNCIONALIDADE',
#    'ATUALIZACAO DE REQUISITOS FUNCIONAIS'): {'support': 15, 'confidence': 13},
#   ('CONSTRUCAO DE FUNCIONALIDADE',
#    'DOCUMENTACAO DE REQUISITOS FUNCIONAIS'): {'support': 15, 'confidence': 13},
#   ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#    'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS'): {'support': 14, 'confidence': 12},
#   ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#    'MANUTENCAO DE FUNCIONALIDADE'): {'support': 15, 'confidence': 13},
#   ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#    'ATUALIZACAO DE REQUISITOS FUNCIONAIS'): {'support': 14, 'confidence': 13},
#   ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#    'MANUTENCAO DE FUNCIONALIDADE'): {'support': 15, 'confidence': 14},
#   ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#    'ATUALIZACAO DE REQUISITOS FUNCIONAIS'): {'support': 15, 'confidence': 13},
#   ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#    'CONSTRUCAO DE FUNCIONALIDADE'): {'support': 15, 'confidence': 13}}}

# %%
conf_result = pm4py.conformance_declare(log, declare_model)
conf_result
# Out:
# [{'no_constr_total': 104,
#   'deviations': [['existence', 'DOCUMENTACAO DE REQUISITOS FUNCIONAIS'],
#    ['responded_existence',
#     ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#      'DOCUMENTACAO DE REQUISITOS FUNCIONAIS')],
#    ['responded_existence',
#     ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#      'DOCUMENTACAO DE REQUISITOS FUNCIONAIS')],
#    ['responded_existence',
#     ('CONSTRUCAO DE FUNCIONALIDADE', 'DOCUMENTACAO DE REQUISITOS FUNCIONAIS')],
#    ['responded_existence',
#     ('MANUTENCAO DE FUNCIONALIDADE', 'DOCUMENTACAO DE REQUISITOS FUNCIONAIS')],
#    ['responded_existence',
#     ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#      'DOCUMENTACAO DE REQUISITOS FUNCIONAIS')],
#    ['coexistence',
#     ('MANUTENCAO DE FUNCIONALIDADE', 'DOCUMENTACAO DE REQUISITOS FUNCIONAIS')],
#    ['coexistence',
#     ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#      'DOCUMENTACAO DE REQUISITOS FUNCIONAIS')],
#    ['coexistence',
#     ('CONSTRUCAO DE FUNCIONALIDADE', 'DOCUMENTACAO DE REQUISITOS FUNCIONAIS')],
#    ['coexistence',
#     ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS', 'MANUTENCAO DE FUNCIONALIDADE')],
#    ['coexistence',
#     ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#      'ATUALIZACAO DE REQUISITOS FUNCIONAIS')],
#    ['coexistence',
#     ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS', 'CONSTRUCAO DE FUNCIONALIDADE')],
#    ['absence', 'ANÁLISE DE RELATOS DE VALIDACAO/HOMOLOGACAO'],
#    ['absence', 'COMPONENTE ARQUITETURAL'],
#    ['absence', 'ATENDIMENTO AOS ACIONAMENTOS DE CLIENTES']],
#   'no_dev_total': 15,
#   'dev_fitness': 0.8557692307692308,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['existence', 'CORRECAO DE ERROS EM FUNCIONALIDADE(S)'],
#    ['responded_existence',
#     ('CONSTRUCAO DE FUNCIONALIDADE',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['responded_existence',
#     ('MANUTENCAO DE FUNCIONALIDADE',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['responded_existence',
#     ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['responded_existence',
#     ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['responded_existence',
#     ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['coexistence',
#     ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['coexistence',
#     ('MANUTENCAO DE FUNCIONALIDADE',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['coexistence',
#     ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['coexistence',
#     ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#      'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['coexistence',
#     ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#      'MANUTENCAO DE FUNCIONALIDADE')],
#    ['coexistence',
#     ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#      'ATUALIZACAO DE REQUISITOS FUNCIONAIS')],
#    ['absence', 'PROTOTIPAR'],
#    ['absence', 'ELABORAR MODELO LÓGICO DE DADOS'],
#    ['absence', 'PARTICIPAR DE EVENTO']],
#   'no_dev_total': 15,
#   'dev_fitness': 0.8557692307692308,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['existence', 'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS'],
#    ['existence', 'ATUALIZACAO DE REQUISITOS FUNCIONAIS'],
#    ['existence', 'CORRECAO DE ERROS EM FUNCIONALIDADE(S)'],
#    ['responded_existence',
#     ('CONSTRUCAO DE FUNCIONALIDADE',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['responded_existence',
#     ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#      'ATUALIZACAO DE REQUISITOS FUNCIONAIS')],
#    ['responded_existence',
#     ('MANUTENCAO DE FUNCIONALIDADE',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['responded_existence',
#     ('CONSTRUCAO DE FUNCIONALIDADE', 'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['responded_existence',
#     ('MANUTENCAO DE FUNCIONALIDADE', 'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['responded_existence',
#     ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['responded_existence',
#     ('CONSTRUCAO DE FUNCIONALIDADE', 'ATUALIZACAO DE REQUISITOS FUNCIONAIS')],
#    ['responded_existence',
#     ('MANUTENCAO DE FUNCIONALIDADE', 'ATUALIZACAO DE REQUISITOS FUNCIONAIS')],
#    ['responded_existence',
#     ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#      'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['coexistence',
#     ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS', 'MANUTENCAO DE FUNCIONALIDADE')],
#    ['coexistence',
#     ('MANUTENCAO DE FUNCIONALIDADE', 'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['coexistence',
#     ('MANUTENCAO DE FUNCIONALIDADE', 'ATUALIZACAO DE REQUISITOS FUNCIONAIS')],
#    ['coexistence',
#     ('MANUTENCAO DE FUNCIONALIDADE',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['coexistence',
#     ('ATUALIZACAO DE REQUISITOS FUNCIONAIS', 'MANUTENCAO DE FUNCIONALIDADE')],
#    ['coexistence',
#     ('ATUALIZACAO DE REQUISITOS FUNCIONAIS', 'CONSTRUCAO DE FUNCIONALIDADE')],
#    ['coexistence',
#     ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#      'DOCUMENTACAO DE REQUISITOS FUNCIONAIS')],
#    ['coexistence',
#     ('CONSTRUCAO DE FUNCIONALIDADE', 'ATUALIZACAO DE REQUISITOS FUNCIONAIS')],
#    ['coexistence',
#     ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#      'MANUTENCAO DE FUNCIONALIDADE')],
#    ['coexistence',
#     ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#      'ATUALIZACAO DE REQUISITOS FUNCIONAIS')]],
#   'no_dev_total': 22,
#   'dev_fitness': 0.7884615384615384,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['absence', 'PROTOTIPAR'],
#    ['absence', 'ANÁLISE DE REUSO E ESPECIFICACAO DE NOVOS COMPONENTES'],
#    ['absence', 'PROPOSTA DE SOLUCAO PROSPECTADA'],
#    ['absence', 'ESPECIFICACAO DE INTEGRACÕES'],
#    ['absence', 'ANÁLISE DE RELATOS DE VALIDACAO/HOMOLOGACAO'],
#    ['absence', 'PLANEJAMENTO DE RELEASE'],
#    ['absence', 'PROSPECCAO DE SOLUCAO'],
#    ['absence', 'CRIACAO/MANUTENCAO DE FUNCIONALIDADE']],
#   'no_dev_total': 8,
#   'dev_fitness': 0.9230769230769231,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['existence', 'CONSTRUCAO DE FUNCIONALIDADE'],
#    ['responded_existence',
#     ('ATUALIZACAO DE REQUISITOS FUNCIONAIS', 'CONSTRUCAO DE FUNCIONALIDADE')],
#    ['responded_existence',
#     ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS', 'CONSTRUCAO DE FUNCIONALIDADE')],
#    ['responded_existence',
#     ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS', 'CONSTRUCAO DE FUNCIONALIDADE')],
#    ['responded_existence',
#     ('MANUTENCAO DE FUNCIONALIDADE', 'CONSTRUCAO DE FUNCIONALIDADE')],
#    ['responded_existence',
#     ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#      'CONSTRUCAO DE FUNCIONALIDADE')],
#    ['coexistence',
#     ('MANUTENCAO DE FUNCIONALIDADE', 'CONSTRUCAO DE FUNCIONALIDADE')],
#    ['coexistence',
#     ('ATUALIZACAO DE REQUISITOS FUNCIONAIS', 'CONSTRUCAO DE FUNCIONALIDADE')],
#    ['coexistence',
#     ('CONSTRUCAO DE FUNCIONALIDADE', 'MANUTENCAO DE FUNCIONALIDADE')],
#    ['coexistence',
#     ('CONSTRUCAO DE FUNCIONALIDADE', 'ATUALIZACAO DE REQUISITOS FUNCIONAIS')],
#    ['coexistence',
#     ('CONSTRUCAO DE FUNCIONALIDADE', 'DOCUMENTACAO DE REQUISITOS FUNCIONAIS')],
#    ['coexistence',
#     ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS', 'CONSTRUCAO DE FUNCIONALIDADE')],
#    ['absence', 'DOCUMENTACAO DE REQUISITOS NAO FUNCIONAIS (NF)'],
#    ['absence', 'MANUTENCAO DE FLUXOS NO ALM OU GIT'],
#    ['absence', 'MUDANCA DE INTERFACE (COSMÉTICA)'],
#    ['absence', 'CRIACAO, CONFIGURACAO E ATUALIZACAO DE AMBIENTE']],
#   'no_dev_total': 16,
#   'dev_fitness': 0.8461538461538461,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['absence', 'PLANEJAMENTO DE ENTREGA'],
#    ['absence', 'MUDANCA DE INTERFACE (COSMÉTICA)'],
#    ['absence', 'CASOS DE TESTES AUTOMATIZADOS']],
#   'no_dev_total': 3,
#   'dev_fitness': 0.9711538461538461,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['existence', 'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS'],
#    ['responded_existence',
#     ('CONSTRUCAO DE FUNCIONALIDADE', 'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['responded_existence',
#     ('MANUTENCAO DE FUNCIONALIDADE', 'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['responded_existence',
#     ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#      'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['responded_existence',
#     ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#      'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['responded_existence',
#     ('DOCUMENTACAO DE REQUISITOS FUNCIONAIS',
#      'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['coexistence',
#     ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS', 'MANUTENCAO DE FUNCIONALIDADE')],
#    ['coexistence',
#     ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#      'ATUALIZACAO DE REQUISITOS FUNCIONAIS')],
#    ['coexistence',
#     ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['coexistence',
#     ('MANUTENCAO DE FUNCIONALIDADE', 'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['coexistence',
#     ('ATUALIZACAO DE REQUISITOS FUNCIONAIS',
#      'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['coexistence',
#     ('CORRECAO DE ERROS EM FUNCIONALIDADE(S)',
#      'EXECUTAR TESTES MANUAIS EXPLORATÓRIOS')],
#    ['absence', 'TESTES INTEGRADOS COM OUTRAS EQUIPES']],
#   'no_dev_total': 13,
#   'dev_fitness': 0.875,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['absence', 'ACOMPANHAMENTO DE MÉTRICAS DO SONAR'],
#    ['absence', 'PROJETO MODELO FÍSICO DE DADOS'],
#    ['absence', 'REEXECUCAO DE APURACAO ESPECIAL COM ALTERACAO DE PARÂMETROS'],
#    ['absence', 'ANÁLISE DE PROBLEMA'],
#    ['absence', 'EVENTO DE KICKOFF, INCEPTION OU DESIGN SPRINT'],
#    ['absence', 'ELABORAR MASSA DE DADOS NO AMBIENTE DE HOMOLOGACAO/VALIDACA']],
#   'no_dev_total': 6,
#   'dev_fitness': 0.9423076923076923,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['absence', 'EXECUTAR TESTES NAO-FUNCIONAIS'],
#    ['absence', 'DEFINICAO ARQUITETURAL DA SOLUCAO'],
#    ['absence', 'ELABORAR CASOS DE TESTES NAO FUNCIONAL'],
#    ['absence', 'CRIACAO, CONFIGURACAO E ATUALIZACAO DE AMBIENTE'],
#    ['absence', 'LEVANTAMENTO DE INFORMACÕES PARA O REGISTRO DE ATIVIDADE DE']],
#   'no_dev_total': 5,
#   'dev_fitness': 0.9519230769230769,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['response',
#     ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS', 'MANUTENCAO DE FUNCIONALIDADE')],
#    ['absence', 'CRIACAO DE ESTRUTURA INICIAL DE INTEGRACAO CONTÍNUA']],
#   'no_dev_total': 2,
#   'dev_fitness': 0.9807692307692307,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['absence', 'EXECUTAR TESTES NAO-FUNCIONAIS'],
#    ['absence', 'ANÁLISE DE PROBLEMA'],
#    ['absence', 'ELABORAR MASSA DE DADOS NO AMBIENTE DE HOMOLOGACAO/VALIDACA'],
#    ['absence', 'REALIZAR HOMOLOGACAO ASSISTIDA']],
#   'no_dev_total': 4,
#   'dev_fitness': 0.9615384615384616,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['absence',
#     'RELATÓRIO DE AVALIACAO DE TESTES FUNCIONAIS (RLT)'],
#    ['absence', 'ATUALIZACAO DE ARQUIVOS DE DADOS DE CÓDIGO (CODE DATA)'],
#    ['absence', 'CRIACAO E CONFIGURACAO DOS AMBIENTES DO NOVO SISTEMA/SOLUCA'],
#    ['absence', 'ATUALIZACAO DE PLATAFORMA DO SISTEMA']],
#   'no_dev_total': 4,
#   'dev_fitness': 0.9615384615384616,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['response',
#     ('EXECUTAR TESTES MANUAIS EXPLORATÓRIOS', 'MANUTENCAO DE FUNCIONALIDADE')],
#    ['absence', 'CODIFICAR ESTRUTURAS DE PÁGINAS, COMPONENTES ETC'],
#    ['absence', 'CRIACAO/MANUTENCAO DE FUNCIONALIDADE'],
#    ['absence', 'PROTOTIPACAO COM UI KIT DO DESIGN SYSTEM']],
#   'no_dev_total': 4,
#   'dev_fitness': 0.9615384615384616,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['absence', 'PROJETO MODELO FÍSICO DE DADOS'],
#    ['absence', 'IDEACAO / RABISCOFRAME'],
#    ['absence', 'CRIACAO, CONFIGURACAO DE USUÁRIO/PERFIL'],
#    ['absence', 'SUPORTE / REPASSE UX'],
#    ['absence', 'ATUALIZACAO DE PLATAFORMA DO SISTEMA'],
#    ['absence', 'TESTES COM USUÁRIOS'],
#    ['absence', 'PROTOTIPACAO COM UI KIT DO DESIGN SYSTEM']],
#   'no_dev_total': 7,
#   'dev_fitness': 0.9326923076923077,
#   'is_fit': False},
#  {'no_constr_total': 104,
#   'deviations': [['precedence',
#     ('MANUTENCAO DE FUNCIONALIDADE',
#      'CORRECAO DE ERROS EM FUNCIONALIDADE(S)')],
#    ['absence', 'PROTOTIPACAO']],
#   'no_dev_total': 2,
#   'dev_fitness': 0.9807692307692307,
#   'is_fit': False}]

# %%
log2 = pm4py.read_xes('Tarefas_preparada.xes')
log2
# Out:
# parsing log, completed traces ::   0%|          | 0/2963 [00:00<?, ?it/s]
#        id_demanda_anonimizado        nm_tipodemanda    nm_linguagem  \
# 0                    39308376  Manutenção Evolutiva            Java
# 1                    39308376  Manutenção Evolutiva            Java
# 2                    39308376  Manutenção Evolutiva            Java
# 3                    39308376  Manutenção Evolutiva            Java
# 4                    39308376  Manutenção Evolutiva            Java
# ...                       ...                   ...             ...
# 97554                81270720  Manutenção Evolutiva         Angular
# 97555                81270720  Manutenção Evolutiva         Angular
# 97556                81303672  Manutenção Evolutiva  Dot Net (.Net)
# 97557                81303672  Manutenção Evolutiva  Dot Net (.Net)
# 97558                81303672  Manutenção Evolutiva  Dot Net (.Net)
#
#       nm_cliente_anomizado  vl_pfrealizado                dt_criacao  \
# 0               Cliente 12           81.15 2018-01-10 00:00:00+00:00
# 1               Cliente 12           81.15 2018-01-10 00:00:00+00:00
# 2               Cliente 12           81.15 2018-01-10 00:00:00+00:00
# 3               Cliente 12           81.15 2018-01-10 00:00:00+00:00
# 4               Cliente 12           81.15 2018-01-10 00:00:00+00:00
# ...                    ...             ...                       ...
# 97554           Cliente 15           20.80 2022-12-08 00:00:00+00:00
# 97555           Cliente 15           20.80 2022-12-08 00:00:00+00:00
# 97556          Sem cliente           14.25 2022-08-15 00:00:00+00:00
# 97557          Sem cliente           14.25 2022-08-15 00:00:00+00:00
# 97558          Sem cliente           14.25 2022-08-15 00:00:00+00:00
#
#           dt_inicio_atendimento    dt_entrega_homologacao  \
# 0     2018-10-22 00:00:00+00:00 2020-12-23 00:00:00+00:00
# 1     2018-10-22 00:00:00+00:00 2020-12-23 00:00:00+00:00
# 2     2018-10-22 00:00:00+00:00 2020-12-23 00:00:00+00:00
# 3     2018-10-22 00:00:00+00:00 2020-12-23 00:00:00+00:00
# 4     2018-10-22 00:00:00+00:00 2020-12-23 00:00:00+00:00
# ...                         ...                       ...
# 97554 2022-05-09 00:00:00+00:00 2022-12-09 00:00:00+00:00
# 97555 2022-05-09 00:00:00+00:00 2022-12-09 00:00:00+00:00
# 97556 2022-08-23 00:00:00+00:00 2022-09-21 00:00:00+00:00
# 97557 2022-08-23 00:00:00+00:00 2022-09-21 00:00:00+00:00
# 97558 2022-08-23 00:00:00+00:00 2022-09-21 00:00:00+00:00
#
#                    dt_conclusao  id_tarefa_anonimizado  ...  duracao_por_pf  \
# 0     2020-12-23 00:00:00+00:00               58148088  ...   113922.365989
# 1     2020-12-23 00:00:00+00:00               57202224  ...   113922.365989
# 2     2020-12-23 00:00:00+00:00               57849168  ...   113922.365989
# 3     2020-12-23 00:00:00+00:00               57849360  ...   113922.365989
# 4     2020-12-23 00:00:00+00:00               57922560  ...   113922.365989
# ...                         ...                    ...  ...             ...
# 97554 2022-12-09 00:00:00+00:00               81821256  ...   120461.538462
# 97555 2022-12-09 00:00:00+00:00               82226712  ...   120461.538462
# 97556 2022-09-21 00:00:00+00:00               81384168  ...   218273.684211
# 97557 2022-09-21 00:00:00+00:00               81383424  ...   218273.684211
# 97558 2022-09-21 00:00:00+00:00               81384048  ...   218273.684211
#
#       dt_conclusao_ultima_tarefa  esforco_declarado_por_pf  \
# 0      2020-12-30 00:00:00+00:00              15992.606285
# 1      2020-12-30 00:00:00+00:00              15992.606285
# 2      2020-12-30 00:00:00+00:00              15992.606285
# 3      2020-12-30 00:00:00+00:00              15992.606285
# 4      2020-12-30 00:00:00+00:00              15992.606285
# ...                          ...                       ...
# 97554  2022-09-21 00:00:00+00:00              38613.461538
# 97555  2022-09-21 00:00:00+00:00              38613.461538
# 97556  2022-09-22 00:00:00+00:00               9094.736842
# 97557  2022-09-22 00:00:00+00:00               9094.736842
# 97558  2022-09-22 00:00:00+00:00               9094.736842
#
#        esforco_total_real_por_pf media_atividades_distintas @@index  \
# 0      2 days 22:41:02.107208872                   4.250000       0
# 1      2 days 22:41:02.107208872                   4.250000       1
# 2      2 days 22:41:02.107208872                   4.250000       2
# 3      2 days 22:41:02.107208872                   4.250000       3
# 4      2 days 22:41:02.107208872                   4.250000       4
# ...                          ...                        ...     ...
# 97554  1 days 01:23:04.615384615                   2.222222   97554
# 97555  1 days 01:23:04.615384615                   2.222222   97555
# 97556  6 days 04:12:37.894736842                   8.000000   97556
# 97557  6 days 04:12:37.894736842                   8.000000   97557
# 97558  6 days 04:12:37.894736842                   8.000000   97558
#
#        @@case_index                                       concept:name  \
# 0                 0               ATUALIZACAO DE REQUISITOS FUNCIONAIS
# 1                 0                       MANUTENCAO DE FUNCIONALIDADE
# 2                 0                   REVISAO DE REQUISITOS FUNCIONAIS
# 3                 0                   REVISAO DE REQUISITOS FUNCIONAIS
# 4                 0                   REVISAO DE REQUISITOS FUNCIONAIS
# ...             ...                                                ...
# 97554          2961                            REPASSE DE CONHECIMENTO
# 97555          2961                       CONSTRUCAO DE FUNCIONALIDADE
# 97556          2962  EXECUTAR TESTES MANUAIS GUIADOS POR CASOS DE T...
# 97557          2962              DOCUMENTACAO DE REQUISITOS FUNCIONAIS
# 97558          2962                       MANUTENCAO DE FUNCIONALIDADE
#
#                  time:timestamp case:concept:name
# 0     2020-01-12 00:00:00+00:00          39308376
# 1     2020-03-11 00:00:00+00:00          39308376
# 2     2020-06-11 00:00:00+00:00          39308376
# 3     2020-06-11 00:00:00+00:00          39308376
# 4     2020-06-11 00:00:00+00:00          39308376
# ...                         ...               ...
# 97554 2022-09-21 00:00:00+00:00          81270720
# 97555 2022-09-21 00:00:00+00:00          81270720
# 97556 2022-08-23 00:00:00+00:00          81303672
# 97557 2022-08-24 00:00:00+00:00          81303672
# 97558 2022-09-13 00:00:00+00:00          81303672
#
# [97559 rows x 31 columns]
