# %% [markdown]
# Passo a passo:
# 1. Receber os logs e modelos como na v1
# 2. Converter o log de atividades para o novo formato, trocando a coluna lifecycle por start e end no nome da atividade
# 3. Converter o log de acesso para o mesmo formato do log de atividades, colocando a operação no nome
# 4. Adaptar o modelo declare para que todas as operações obrigatórias e proibidas do modelo de acesso virem regras declare
#
#
# **Parei porque as regras succession e not succession não estavam implementadas ainda e o nome das atividades dava erro as vezes**

# %%
from Declare4Py.ProcessModels.DeclareModel import DeclareModel

def check_letters(cell, modelo, acesso, atividade):
    """Verifica quais letras (c, r, u, d) estão presentes na célula, diferenciando maiúsculas e minúsculas."""
    # Letras a serem verificadas
    letters = ['c', 'r', 'u', 'd']
    
    cell = str(cell)  # Garantir que a célula é string
    for letter in letters:
        lowercase_present = letter in cell
        uppercase_present = letter.upper() in cell
        
        if uppercase_present:
            modelo += f'Succession[{atividade} - begin, {acesso} - {letter}] | | |\n'
            modelo += f'Succesion[{acesso} - {letter}, {atividade} - complete] | | |\n'
        if not lowercase_present and not uppercase_present:
            modelo += f'NotSuccession[{atividade} - begin, {acesso} - {letter}] | | |\n'
            modelo += f'NotSuccession[{acesso} - {letter}, {atividade} - complete] | | |\n'
    
    return modelo
    

def convertModelToRules(modeloAcesso, modeloProcesso):
    declare_model_activities = modeloProcesso.activities
    declare_model_constraints = modeloProcesso.serialized_constraints
    
    novoModelo = ''
    
    for act in declare_model_activities:
        novoModelo += 'activity ' + act + '\n'
    
    for rule in declare_model_constraints:
        novoModelo += rule + '\n'

    # Criar um novo DataFrame com os resultados
    for col in modeloAcesso.columns:
        for index, value in modeloAcesso[col].items():
            novoModelo = check_letters(value, novoModelo, modeloAcesso.iloc[index,0], col)
    
    declare_model = DeclareModel().parse_from_string(novoModelo)
    return declare_model

# %%
import pandas as pd
from Declare4Py.ProcessModels.DeclareModel import DeclareModel
from Declare4Py.D4PyEventLog import D4PyEventLog
import pm4py

def PreProcessData(logProcessoPATH, logAcessoPATH, modeloRecursoPATH, modeloProcessoPATH, modeloAcessoPATH):
    logAcesso = D4PyEventLog(case_name="case:concept:name")
    logAcesso.parse_xes_log(logAcessoPATH)
    logAcessoProcessado = pm4py.convert_to_dataframe(logAcesso.get_log())
    logAcessoProcessado = logAcessoProcessado.sort_values(['case:concept:name', 'concept:instance'])
    modeloRecursoProcessado = pd.read_csv(modeloRecursoPATH, sep=';')
    modeloAcessoProcessado = pd.read_csv(modeloAcessoPATH, sep=';')
    declare_model = DeclareModel().parse_from_file(modeloProcessoPATH)
    event_log = D4PyEventLog(case_name="case:concept:name")
    event_log.parse_xes_log(logProcessoPATH)
    return event_log, logAcessoProcessado, modeloRecursoProcessado, declare_model, modeloAcessoProcessado

# %%
import pm4py

def convertLogs(logProcesso, logAcesso):
    '''
    Converte os logs de processo e acesso em um log único que pode ser submetido a verificação de conformidade 
    por meio da biblioteca Declare4Py 
    '''
    logProcessoCSV = pm4py.convert_to_dataframe(logProcesso.get_log())
    logProcessoCSV = logProcessoCSV.sort_values(['case:concept:name', 'concept:instance'])
    for index, row in logProcessoCSV.iterrows():
        logProcessoCSV.at[index, 'concept:name'] = row['concept:name'] + ' - ' + row['lifecycle:transition']
    logProcessoCSV.drop('lifecycle:transition', axis=1, inplace=True)
    
    for index, row in logAcesso.iterrows():
        logProcessoCSV.loc[len(logProcessoCSV)] = [(row['concept:tool'] + " - " + row['concept:operation'].lower()), row['time:timestamp'], row['concept:resource'], row['concept:instance'], len(logProcessoCSV), row['@@case_index'], row['case:concept:name']]
    logProcessoCSV.sort_values(['case:concept:name', 'concept:instance'])
    logProcessoCSV = logProcessoCSV.reset_index(drop=True)  
    pm4py.write_xes(logProcessoCSV, "LogSinteticoConjuntoOFICIAL.xes")

# %%
def formatViolations(df_violations):
    '''
    Formata as violações encontradas na verificação de conformidade do Declare4Py
    '''
    violacoes = []
    for index, row in df_violations.iterrows():
        for coluna in df_violations.columns:
            if row[coluna] == 1:
                violacoes.append(f"Trace {index} violou {coluna}")
    return violacoes

# %%
from Declare4Py.ProcessMiningTasks.ConformanceChecking.MPDeclareAnalyzer import MPDeclareAnalyzer
from Declare4Py.ProcessMiningTasks.ConformanceChecking.MPDeclareResultsBrowser import MPDeclareResultsBrowser

def CheckProcessConformance(modeloProcesso):
    '''
    Checa conformidade de processo entre o log e o modelo DECLARE com a biblioteca Declare4Py
    Recebe um log de processo (em formato EventLog) e um modelo de processo (em DeclareModel)
    
    '''
    event_log = D4PyEventLog(case_name="case:concept:name")
    event_log.parse_xes_log("LogSinteticoConjuntoOFICIAL.xes")
    
    model_constraints = modeloProcesso.get_decl_model_constraints()

    print("Model constraints:")
    print("-----------------")
    for idx, constr in enumerate(model_constraints):
        print(idx, constr)
    basic_checker = MPDeclareAnalyzer(log=event_log, declare_model=modeloProcesso, consider_vacuity=False)
    conf_check_res: MPDeclareResultsBrowser = basic_checker.run()
    violacoes = formatViolations(conf_check_res.get_metric(metric="num_violations"))
    return violacoes

# %%
import pm4py

def CheckResourceConformance(logProcesso, logAcesso, modeloRecurso):
    '''
    Checa conformidade entre o log de acesso, log de processo e o modelo de recurso
    Recebe modelo de recurso e logs em csv
    '''
    
    logProcessoCSV = pm4py.convert_to_dataframe(logProcesso.get_log())
    logProcessoCSV = logProcessoCSV.sort_values(['case:concept:name', 'concept:instance'])
    logProcessoFiltrado = logProcessoCSV[logProcessoCSV["lifecycle:transition"] == "begin"]
    
    violacoes = {}
    violacoes["AcessoRecursoEquipe"] = []
    violacoes["AcessoRecursoErrado"] = []
    violacoes["Atividade"] = []
    for index, row in modeloRecurso.iterrows():
        demanda = row['case:concept:name']
        recursos = row['concept:resources'].split(", ")
        atividades = logProcessoFiltrado[logProcessoFiltrado['case:concept:name'] == demanda]
        acessos = logAcesso[logAcesso['case:concept:name'] == demanda]
        for i, atv in atividades.iterrows():
            recursoAtv = atv['concept:resource']
            if recursoAtv not in recursos:
                violacoes["Atividade"].append([atv['concept:name'], demanda, recursoAtv])
            
            acessosAtv = acessos[acessos['concept:instance']== atv['concept:instance']]
            for j, acc in acessosAtv.iterrows():
                if recursoAtv != acc['concept:resource']:
                    violacoes["AcessoRecursoErrado"].append([acc['concept:tool'], demanda, acc['concept:resource'], recursoAtv])
                if acc['concept:resource'] not in recursos:
                    violacoes["AcessoRecursoEquipe"].append([acc['concept:tool'], demanda, acc['concept:resource']])
    return violacoes

# %%
def formatInconformances(conformanceProcess, conformanceResource):
    '''
    Formata as inconformidades encontradas em cada verificação (pode vir a combinar os padrões de anomalias no futuro)
    '''
    print('Violações de fluxo de processo:')
    for violation in conformanceProcess:
        print(violation)
    
    # print("Violações de Acesso:")
    # for key, violation in conformanceAcess.items():
    #     if key == "OperacaoProibida":
    #         for occur in violation:
    #             print(f'Violação de Acesso na atividade {occur[0]} no trace {occur[1]}, a operação {occur[2]} não era permitida para a ferramenta {occur[3]}')
    #     if key == "AcessoObgNaoRealizado":
    #         for occur in violation:
    #             print(f"Violação de Acesso na atividade {occur[0]} no trace {occur[1]}, os acessos obrigatórios às ferramentas {occur[2]} não foram realizados")
    
    
    print('Violações de Privacidade:')
    for key, violation in conformanceResource.items():
        if key == "Atividade":
            for occur in violation:
                print(f'Violação de Privacidade na atividade {occur[0]} no trace {occur[1]}, o recurso {occur[2]} não faz parte da equipe determinada para realizar a demanda')
        if key == "AcessoRecursoEquipe":
            for occur in violation:
                print(f'Violação de Privacidade no acesso a {occur[0]} no trace {occur[1]}, o recurso {occur[2]} não faz parte da equipe determinada para realizar a demanda')
        if key == "AcessoRecursoErrado":
            for occur in violation:
                print(f'Violação de Privacidade no acesso a {occur[0]} no trace {occur[1]}, o recurso {occur[2]} não era o designado da atividade vinculada e sim o {occur[3]}')

# %%
def MultiperspectiveConformanceAlgorithm(logProcessoPATH, logAcessoPATH, modeloRecursoPATH, modeloProcessoPATH, modeloAcessoPATH):
  '''
  O algoritmo recebe: um log de processo, um log de acesso a dados, um modelo de recurso, um modelo DECLARE de processo e um modelo de acesso a dados
  '''
  logProcesso, logAcesso, modeloRecurso, modeloProcesso, modeloAcesso = PreProcessData(logProcessoPATH, logAcessoPATH, modeloRecursoPATH, modeloProcessoPATH, modeloAcessoPATH)
  modeloAcessoConvertido = convertModelToRules(modeloAcesso, modeloProcesso)
  convertLogs(logProcesso, logAcesso)
  conformanceProcess = CheckProcessConformance(modeloAcessoConvertido)
  conformanceResource = CheckResourceConformance(logProcesso, logAcesso, modeloRecurso)
  return formatInconformances(conformanceProcess, conformanceResource)

# %%
MultiperspectiveConformanceAlgorithm('./LogSinteticoProcessoOFICIAL.xes', './LogSinteticoAcessoOFICIAL.xes', './ModeloRecursosOFICIAL.csv', './Modelo_Log_Sintetico_OFICIAL.decl', './ModeloAcessoOFICIAL.csv')
# Out:
# parsing log, completed traces :: 100%|██████████| 2000/2000 [00:06<00:00, 286.76it/s]
# parsing log, completed traces :: 100%|██████████| 2000/2000 [00:02<00:00, 861.05it/s]
# exporting log, completed traces :: 100%|██████████| 2000/2000 [00:07<00:00, 256.14it/s]
# parsing log, completed traces :: 100%|██████████| 2000/2000 [00:09<00:00, 222.15it/s]
# Model constraints:
# -----------------
# 0 Existence1[Contagem de ponto de funcao] | |
# 1 Existence1[Gestao da demanda] | |
# 2 Existence1[Planejamento de entrega] | |
# 3 Existence1[Review da entrega] | |
# 4 Existence1[Publicar solucao] | |
# 5 Response[Atualizacao de requisitos funcionais, Manutencao de funcionalidade] | | |
# 6 Response[Documentacao de requisitos funcionais, Construcao de funcionalidade] | | |
# 7 Response[Planejamento de entrega, Review da entrega] | | |
# 8 Response[Construcao de funcionalidade, Publicar solucao] | | |
# 9 Response[Manutencao de funcionalidade, Publicar solucao] | | |
# 10 Existence1[Elaborar caso de teste] | |
# 11 Existence1[Executar teste] | |
# 12 Response[Elaborar caso de teste, Executar teste] | | |
# 13 Response[Documentacao de requisitos funcionais, Elaborar caso de teste] | | |
# 14 Response[Atualizacao de requisitos funcionais, Elaborar caso de teste] | | |
# 15 Precedence[Corrigir erro, Executar teste] | | |
# 16 Precedence[Documentacao de requisitos funcionais, Elaborar caso de teste] | | |
# 17 Precedence[Atualizacao de requisitos funcionais, Elaborar caso de teste] | | |
# 18 Not Succession[Ferramenta - begin, Gestao - c] | | |
# 19 Not Succession[Gestao - c, Ferramenta - complete] | | |
# 20 Not Succession[Ferramenta - begin, Gestao - r] | | |
# 21 Not Succession[Gestao - r, Ferramenta - complete] | | |
# 22 Not Succession[Ferramenta - begin, Gestao - u] | | |
# 23 Not Succession[Gestao - u, Ferramenta - complete] | | |
# 24 Not Succession[Ferramenta - begin, Gestao - d] | | |
# 25 Not Succession[Gestao - d, Ferramenta - complete] | | |
# 26 Precedence[Ferramenta - begin, Codigo - c] | | |
# 27 Precedence[Codigo - c, Ferramenta - complete] | | |
# 28 Not Succession[Ferramenta - begin, Codigo - r] | | |
# 29 Not Succession[Codigo - r, Ferramenta - complete] | | |
# 30 Not Succession[Ferramenta - begin, Codigo - u] | | |
# 31 Not Succession[Codigo - u, Ferramenta - complete] | | |
# 32 Not Succession[Ferramenta - begin, Requisito - c] | | |
# 33 Not Succession[Requisito - c, Ferramenta - complete] | | |
# 34 Precedence[Ferramenta - begin, Requisito - r] | | |
# 35 Precedence[Requisito - r, Ferramenta - complete] | | |
# 36 Not Succession[Ferramenta - begin, Requisito - d] | | |
# 37 Not Succession[Requisito - d, Ferramenta - complete] | | |
# 38 Not Succession[Ferramenta - begin, PF - c] | | |
# 39 Not Succession[PF - c, Ferramenta - complete] | | |
# 40 Not Succession[Ferramenta - begin, PF - r] | | |
# 41 Not Succession[PF - r, Ferramenta - complete] | | |
# 42 Not Succession[Ferramenta - begin, PF - u] | | |
# 43 Not Succession[PF - u, Ferramenta - complete] | | |
# 44 Not Succession[Ferramenta - begin, PF - d] | | |
# 45 Not Succession[PF - d, Ferramenta - complete] | | |
# 46 Not Succession[Ferramenta - begin, Teste - c] | | |
# 47 Not Succession[Teste - c, Ferramenta - complete] | | |
# 48 Not Succession[Ferramenta - begin, Teste - r] | | |
# 49 Not Succession[Teste - r, Ferramenta - complete] | | |
# 50 Not Succession[Ferramenta - begin, Teste - u] | | |
# 51 Not Succession[Teste - u, Ferramenta - complete] | | |
# 52 Not Succession[Ferramenta - begin, Teste - d] | | |
# 53 Not Succession[Teste - d, Ferramenta - complete] | | |
# 54 Precedence[Manutencao de funcionalidade - begin, Gestao - u] | | |
# 55 Precedence[Gestao - u, Manutencao de funcionalidade - complete] | | |
# 56 Not Succession[Manutencao de funcionalidade - begin, Codigo - c] | | |
# 57 Not Succession[Codigo - c, Manutencao de funcionalidade - complete] | | |
# 58 Precedence[Manutencao de funcionalidade - begin, Codigo - u] | | |
# 59 Precedence[Codigo - u, Manutencao de funcionalidade - complete] | | |
# 60 Not Succession[Manutencao de funcionalidade - begin, Requisito - c] | | |
# 61 Not Succession[Requisito - c, Manutencao de funcionalidade - complete] | | |
# 62 Not Succession[Manutencao de funcionalidade - begin, Requisito - u] | | |
# 63 Not Succession[Requisito - u, Manutencao de funcionalidade - complete] | | |
# 64 Not Succession[Manutencao de funcionalidade - begin, Requisito - d] | | |
# 65 Not Succession[Requisito - d, Manutencao de funcionalidade - complete] | | |
# 66 Not Succession[Manutencao de funcionalidade - begin, PF - c] | | |
# 67 Not Succession[PF - c, Manutencao de funcionalidade - complete] | | |
# 68 Not Succession[Manutencao de funcionalidade - begin, PF - r] | | |
# 69 Not Succession[PF - r, Manutencao de funcionalidade - complete] | | |
# 70 Not Succession[Manutencao de funcionalidade - begin, PF - u] | | |
# 71 Not Succession[PF - u, Manutencao de funcionalidade - complete] | | |
# 72 Not Succession[Manutencao de funcionalidade - begin, PF - d] | | |
# 73 Not Succession[PF - d, Manutencao de funcionalidade - complete] | | |
# 74 Not Succession[Manutencao de funcionalidade - begin, Teste - c] | | |
# 75 Not Succession[Teste - c, Manutencao de funcionalidade - complete] | | |
# 76 Not Succession[Manutencao de funcionalidade - begin, Teste - u] | | |
# 77 Not Succession[Teste - u, Manutencao de funcionalidade - complete] | | |
# 78 Not Succession[Manutencao de funcionalidade - begin, Teste - d] | | |
# 79 Not Succession[Teste - d, Manutencao de funcionalidade - complete] | | |
# 80 Precedence[Atualizacao de requisitos funcionais - begin, Gestao - u] | | |
# 81 Precedence[Gestao - u, Atualizacao de requisitos funcionais - complete] | | |
# 82 Not Succession[Atualizacao de requisitos funcionais - begin, Codigo - c] | | |
# 83 Not Succession[Codigo - c, Atualizacao de requisitos funcionais - complete] | | |
# 84 Not Succession[Atualizacao de requisitos funcionais - begin, Codigo - u] | | |
# 85 Not Succession[Codigo - u, Atualizacao de requisitos funcionais - complete] | | |
# 86 Not Succession[Atualizacao de requisitos funcionais - begin, Codigo - d] | | |
# 87 Not Succession[Codigo - d, Atualizacao de requisitos funcionais - complete] | | |
# 88 Not Succession[Atualizacao de requisitos funcionais - begin, Requisito - c] | | |
# 89 Not Succession[Requisito - c, Atualizacao de requisitos funcionais - complete] | | |
# 90 Precedence[Atualizacao de requisitos funcionais - begin, Requisito - u] | | |
# 91 Precedence[Requisito - u, Atualizacao de requisitos funcionais - complete] | | |
# 92 Not Succession[Atualizacao de requisitos funcionais - begin, PF - c] | | |
# 93 Not Succession[PF - c, Atualizacao de requisitos funcionais - complete] | | |
# 94 Not Succession[Atualizacao de requisitos funcionais - begin, PF - r] | | |
# 95 Not Succession[PF - r, Atualizacao de requisitos funcionais - complete] | | |
# 96 Not Succession[Atualizacao de requisitos funcionais - begin, PF - u] | | |
# 97 Not Succession[PF - u, Atualizacao de requisitos funcionais - complete] | | |
# 98 Not Succession[Atualizacao de requisitos funcionais - begin, PF - d] | | |
# 99 Not Succession[PF - d, Atualizacao de requisitos funcionais - complete] | | |
# 100 Not Succession[Atualizacao de requisitos funcionais - begin, Teste - c] | | |
# 101 Not Succession[Teste - c, Atualizacao de requisitos funcionais - complete] | | |
# 102 Not Succession[Atualizacao de requisitos funcionais - begin, Teste - u] | | |
# 103 Not Succession[Teste - u, Atualizacao de requisitos funcionais - complete] | | |
# 104 Not Succession[Atualizacao de requisitos funcionais - begin, Teste - d] | | |
# 105 Not Succession[Teste - d, Atualizacao de requisitos funcionais - complete] | | |
# 106 Precedence[Construcao de funcionalidade - begin, Gestao - u] | | |
# 107 Precedence[Gestao - u, Construcao de funcionalidade - complete] | | |
# 108 Precedence[Construcao de funcionalidade - begin, Codigo - c] | | |
# 109 Precedence[Codigo - c, Construcao de funcionalidade - complete] | | |
# 110 Not Succession[Construcao de funcionalidade - begin, Requisito - c] | | |
# 111 Not Succession[Requisito - c, Construcao de funcionalidade - complete] | | |
# 112 Not Succession[Construcao de funcionalidade - begin, Requisito - u] | | |
# 113 Not Succession[Requisito - u, Construcao de funcionalidade - complete] | | |
# 114 Not Succession[Construcao de funcionalidade - begin, Requisito - d] | | |
# 115 Not Succession[Requisito - d, Construcao de funcionalidade - complete] | | |
# 116 Not Succession[Construcao de funcionalidade - begin, PF - c] | | |
# 117 Not Succession[PF - c, Construcao de funcionalidade - complete] | | |
# 118 Not Succession[Construcao de funcionalidade - begin, PF - r] | | |
# 119 Not Succession[PF - r, Construcao de funcionalidade - complete] | | |
# 120 Not Succession[Construcao de funcionalidade - begin, PF - u] | | |
# 121 Not Succession[PF - u, Construcao de funcionalidade - complete] | | |
# 122 Not Succession[Construcao de funcionalidade - begin, PF - d] | | |
# 123 Not Succession[PF - d, Construcao de funcionalidade - complete] | | |
# 124 Not Succession[Construcao de funcionalidade - begin, Teste - c] | | |
# 125 Not Succession[Teste - c, Construcao de funcionalidade - complete] | | |
# 126 Not Succession[Construcao de funcionalidade - begin, Teste - u] | | |
# 127 Not Succession[Teste - u, Construcao de funcionalidade - complete] | | |
# 128 Not Succession[Construcao de funcionalidade - begin, Teste - d] | | |
# 129 Not Succession[Teste - d, Construcao de funcionalidade - complete] | | |
# 130 Precedence[Documentacao de requisitos funcionais - begin, Gestao - u] | | |
# 131 Precedence[Gestao - u, Documentacao de requisitos funcionais - complete] | | |
# 132 Not Succession[Documentacao de requisitos funcionais - begin, Codigo - c] | | |
# 133 Not Succession[Codigo - c, Documentacao de requisitos funcionais - complete] | | |
# 134 Not Succession[Documentacao de requisitos funcionais - begin, Codigo - u] | | |
# 135 Not Succession[Codigo - u, Documentacao de requisitos funcionais - complete] | | |
# 136 Not Succession[Documentacao de requisitos funcionais - begin, Codigo - d] | | |
# 137 Not Succession[Codigo - d, Documentacao de requisitos funcionais - complete] | | |
# 138 Precedence[Documentacao de requisitos funcionais - begin, Requisito - c] | | |
# 139 Precedence[Requisito - c, Documentacao de requisitos funcionais - complete] | | |
# 140 Not Succession[Documentacao de requisitos funcionais - begin, PF - c] | | |
# 141 Not Succession[PF - c, Documentacao de requisitos funcionais - complete] | | |
# 142 Not Succession[Documentacao de requisitos funcionais - begin, PF - r] | | |
# 143 Not Succession[PF - r, Documentacao de requisitos funcionais - complete] | | |
# 144 Not Succession[Documentacao de requisitos funcionais - begin, PF - u] | | |
# 145 Not Succession[PF - u, Documentacao de requisitos funcionais - complete] | | |
# 146 Not Succession[Documentacao de requisitos funcionais - begin, PF - d] | | |
# 147 Not Succession[PF - d, Documentacao de requisitos funcionais - complete] | | |
# 148 Not Succession[Documentacao de requisitos funcionais - begin, Teste - c] | | |
# 149 Not Succession[Teste - c, Documentacao de requisitos funcionais - complete] | | |
# 150 Not Succession[Documentacao de requisitos funcionais - begin, Teste - u] | | |
# 151 Not Succession[Teste - u, Documentacao de requisitos funcionais - complete] | | |
# 152 Not Succession[Documentacao de requisitos funcionais - begin, Teste - d] | | |
# 153 Not Succession[Teste - d, Documentacao de requisitos funcionais - complete] | | |
# 154 Precedence[Contagem de ponto de funcao - begin, Gestao - u] | | |
# 155 Precedence[Gestao - u, Contagem de ponto de funcao - complete] | | |
# 156 Not Succession[Contagem de ponto de funcao - begin, Codigo - c] | | |
# 157 Not Succession[Codigo - c, Contagem de ponto de funcao - complete] | | |
# 158 Not Succession[Contagem de ponto de funcao - begin, Codigo - u] | | |
# 159 Not Succession[Codigo - u, Contagem de ponto de funcao - complete] | | |
# 160 Not Succession[Contagem de ponto de funcao - begin, Codigo - d] | | |
# 161 Not Succession[Codigo - d, Contagem de ponto de funcao - complete] | | |
# 162 Not Succession[Contagem de ponto de funcao - begin, Requisito - c] | | |
# 163 Not Succession[Requisito - c, Contagem de ponto de funcao - complete] | | |
# 164 Not Succession[Contagem de ponto de funcao - begin, Requisito - u] | | |
# 165 Not Succession[Requisito - u, Contagem de ponto de funcao - complete] | | |
# 166 Not Succession[Contagem de ponto de funcao - begin, Requisito - d] | | |
# 167 Not Succession[Requisito - d, Contagem de ponto de funcao - complete] | | |
# 168 Precedence[Contagem de ponto de funcao - begin, PF - c] | | |
# 169 Precedence[PF - c, Contagem de ponto de funcao - complete] | | |
# 170 Not Succession[Contagem de ponto de funcao - begin, Teste - c] | | |
# 171 Not Succession[Teste - c, Contagem de ponto de funcao - complete] | | |
# 172 Not Succession[Contagem de ponto de funcao - begin, Teste - r] | | |
# 173 Not Succession[Teste - r, Contagem de ponto de funcao - complete] | | |
# 174 Not Succession[Contagem de ponto de funcao - begin, Teste - u] | | |
# 175 Not Succession[Teste - u, Contagem de ponto de funcao - complete] | | |
# 176 Not Succession[Contagem de ponto de funcao - begin, Teste - d] | | |
# 177 Not Succession[Teste - d, Contagem de ponto de funcao - complete] | | |
# 178 Precedence[Gestao da demanda - begin, Gestao - u] | | |
# 179 Precedence[Gestao - u, Gestao da demanda - complete] | | |
# 180 Not Succession[Gestao da demanda - begin, Codigo - c] | | |
# 181 Not Succession[Codigo - c, Gestao da demanda - complete] | | |
# 182 Not Succession[Gestao da demanda - begin, Codigo - r] | | |
# 183 Not Succession[Codigo - r, Gestao da demanda - complete] | | |
# 184 Not Succession[Gestao da demanda - begin, Codigo - u] | | |
# 185 Not Succession[Codigo - u, Gestao da demanda - complete] | | |
# 186 Not Succession[Gestao da demanda - begin, Codigo - d] | | |
# 187 Not Succession[Codigo - d, Gestao da demanda - complete] | | |
# 188 Not Succession[Gestao da demanda - begin, Requisito - c] | | |
# 189 Not Succession[Requisito - c, Gestao da demanda - complete] | | |
# 190 Not Succession[Gestao da demanda - begin, Requisito - r] | | |
# 191 Not Succession[Requisito - r, Gestao da demanda - complete] | | |
# 192 Not Succession[Gestao da demanda - begin, Requisito - u] | | |
# 193 Not Succession[Requisito - u, Gestao da demanda - complete] | | |
# 194 Not Succession[Gestao da demanda - begin, Requisito - d] | | |
# 195 Not Succession[Requisito - d, Gestao da demanda - complete] | | |
# 196 Not Succession[Gestao da demanda - begin, PF - c] | | |
# 197 Not Succession[PF - c, Gestao da demanda - complete] | | |
# 198 Not Succession[Gestao da demanda - begin, PF - r] | | |
# 199 Not Succession[PF - r, Gestao da demanda - complete] | | |
# 200 Not Succession[Gestao da demanda - begin, PF - u] | | |
# 201 Not Succession[PF - u, Gestao da demanda - complete] | | |
# 202 Not Succession[Gestao da demanda - begin, PF - d] | | |
# 203 Not Succession[PF - d, Gestao da demanda - complete] | | |
# 204 Not Succession[Gestao da demanda - begin, Teste - c] | | |
# 205 Not Succession[Teste - c, Gestao da demanda - complete] | | |
# 206 Not Succession[Gestao da demanda - begin, Teste - r] | | |
# 207 Not Succession[Teste - r, Gestao da demanda - complete] | | |
# 208 Not Succession[Gestao da demanda - begin, Teste - u] | | |
# 209 Not Succession[Teste - u, Gestao da demanda - complete] | | |
# 210 Not Succession[Gestao da demanda - begin, Teste - d] | | |
# 211 Not Succession[Teste - d, Gestao da demanda - complete] | | |
# 212 Precedence[Planejamento de entrega - begin, Gestao - u] | | |
# 213 Precedence[Gestao - u, Planejamento de entrega - complete] | | |
# 214 Not Succession[Planejamento de entrega - begin, Codigo - c] | | |
# 215 Not Succession[Codigo - c, Planejamento de entrega - complete] | | |
# 216 Not Succession[Planejamento de entrega - begin, Codigo - r] | | |
# 217 Not Succession[Codigo - r, Planejamento de entrega - complete] | | |
# 218 Not Succession[Planejamento de entrega - begin, Codigo - u] | | |
# 219 Not Succession[Codigo - u, Planejamento de entrega - complete] | | |
# 220 Not Succession[Planejamento de entrega - begin, Codigo - d] | | |
# 221 Not Succession[Codigo - d, Planejamento de entrega - complete] | | |
# 222 Not Succession[Planejamento de entrega - begin, Requisito - c] | | |
# 223 Not Succession[Requisito - c, Planejamento de entrega - complete] | | |
# 224 Not Succession[Planejamento de entrega - begin, Requisito - u] | | |
# 225 Not Succession[Requisito - u, Planejamento de entrega - complete] | | |
# 226 Not Succession[Planejamento de entrega - begin, Requisito - d] | | |
# 227 Not Succession[Requisito - d, Planejamento de entrega - complete] | | |
# 228 Not Succession[Planejamento de entrega - begin, PF - c] | | |
# 229 Not Succession[PF - c, Planejamento de entrega - complete] | | |
# 230 Not Succession[Planejamento de entrega - begin, PF - u] | | |
# 231 Not Succession[PF - u, Planejamento de entrega - complete] | | |
# 232 Not Succession[Planejamento de entrega - begin, PF - d] | | |
# 233 Not Succession[PF - d, Planejamento de entrega - complete] | | |
# 234 Not Succession[Planejamento de entrega - begin, Teste - c] | | |
# 235 Not Succession[Teste - c, Planejamento de entrega - complete] | | |
# 236 Not Succession[Planejamento de entrega - begin, Teste - u] | | |
# 237 Not Succession[Teste - u, Planejamento de entrega - complete] | | |
# 238 Not Succession[Planejamento de entrega - begin, Teste - d] | | |
# 239 Not Succession[Teste - d, Planejamento de entrega - complete] | | |
# 240 Precedence[Review da entrega - begin, Gestao - u] | | |
# 241 Precedence[Gestao - u, Review da entrega - complete] | | |
# 242 Not Succession[Review da entrega - begin, Codigo - c] | | |
# 243 Not Succession[Codigo - c, Review da entrega - complete] | | |
# 244 Not Succession[Review da entrega - begin, Codigo - r] | | |
# 245 Not Succession[Codigo - r, Review da entrega - complete] | | |
# 246 Not Succession[Review da entrega - begin, Codigo - u] | | |
# 247 Not Succession[Codigo - u, Review da entrega - complete] | | |
# 248 Not Succession[Review da entrega - begin, Codigo - d] | | |
# 249 Not Succession[Codigo - d, Review da entrega - complete] | | |
# 250 Not Succession[Review da entrega - begin, Requisito - c] | | |
# 251 Not Succession[Requisito - c, Review da entrega - complete] | | |
# 252 Not Succession[Review da entrega - begin, Requisito - u] | | |
# 253 Not Succession[Requisito - u, Review da entrega - complete] | | |
# 254 Not Succession[Review da entrega - begin, Requisito - d] | | |
# 255 Not Succession[Requisito - d, Review da entrega - complete] | | |
# 256 Not Succession[Review da entrega - begin, PF - c] | | |
# 257 Not Succession[PF - c, Review da entrega - complete] | | |
# 258 Not Succession[Review da entrega - begin, PF - r] | | |
# 259 Not Succession[PF - r, Review da entrega - complete] | | |
# 260 Not Succession[Review da entrega - begin, PF - u] | | |
# 261 Not Succession[PF - u, Review da entrega - complete] | | |
# 262 Not Succession[Review da entrega - begin, PF - d] | | |
# 263 Not Succession[PF - d, Review da entrega - complete] | | |
# 264 Not Succession[Review da entrega - begin, Teste - c] | | |
# 265 Not Succession[Teste - c, Review da entrega - complete] | | |
# 266 Not Succession[Review da entrega - begin, Teste - u] | | |
# 267 Not Succession[Teste - u, Review da entrega - complete] | | |
# 268 Not Succession[Review da entrega - begin, Teste - d] | | |
# 269 Not Succession[Teste - d, Review da entrega - complete] | | |
# 270 Precedence[Publicar solucao - begin, Gestao - u] | | |
# 271 Precedence[Gestao - u, Publicar solucao - complete] | | |
# 272 Not Succession[Publicar solucao - begin, Codigo - c] | | |
# 273 Not Succession[Codigo - c, Publicar solucao - complete] | | |
# 274 Not Succession[Publicar solucao - begin, Codigo - r] | | |
# 275 Not Succession[Codigo - r, Publicar solucao - complete] | | |
# 276 Not Succession[Publicar solucao - begin, Codigo - u] | | |
# 277 Not Succession[Codigo - u, Publicar solucao - complete] | | |
# 278 Not Succession[Publicar solucao - begin, Codigo - d] | | |
# 279 Not Succession[Codigo - d, Publicar solucao - complete] | | |
# 280 Not Succession[Publicar solucao - begin, Requisito - c] | | |
# 281 Not Succession[Requisito - c, Publicar solucao - complete] | | |
# 282 Not Succession[Publicar solucao - begin, Requisito - r] | | |
# 283 Not Succession[Requisito - r, Publicar solucao - complete] | | |
# 284 Not Succession[Publicar solucao - begin, Requisito - u] | | |
# 285 Not Succession[Requisito - u, Publicar solucao - complete] | | |
# 286 Not Succession[Publicar solucao - begin, Requisito - d] | | |
# 287 Not Succession[Requisito - d, Publicar solucao - complete] | | |
# 288 Not Succession[Publicar solucao - begin, PF - c] | | |
# 289 Not Succession[PF - c, Publicar solucao - complete] | | |
# 290 Not Succession[Publicar solucao - begin, PF - r] | | |
# 291 Not Succession[PF - r, Publicar solucao - complete] | | |
# 292 Not Succession[Publicar solucao - begin, PF - u] | | |
# 293 Not Succession[PF - u, Publicar solucao - complete] | | |
# 294 Not Succession[Publicar solucao - begin, PF - d] | | |
# 295 Not Succession[PF - d, Publicar solucao - complete] | | |
# 296 Not Succession[Publicar solucao - begin, Teste - c] | | |
# 297 Not Succession[Teste - c, Publicar solucao - complete] | | |
# 298 Not Succession[Publicar solucao - begin, Teste - r] | | |
# 299 Not Succession[Teste - r, Publicar solucao - complete] | | |
# 300 Not Succession[Publicar solucao - begin, Teste - u] | | |
# 301 Not Succession[Teste - u, Publicar solucao - complete] | | |
# 302 Not Succession[Publicar solucao - begin, Teste - d] | | |
# 303 Not Succession[Teste - d, Publicar solucao - complete] | | |
# 304 Precedence[Elaborar caso de teste - begin, Gestao - u] | | |
# 305 Precedence[Gestao - u, Elaborar caso de teste - complete] | | |
# 306 Not Succession[Elaborar caso de teste - begin, Codigo - c] | | |
# 307 Not Succession[Codigo - c, Elaborar caso de teste - complete] | | |
# 308 Not Succession[Elaborar caso de teste - begin, Codigo - u] | | |
# 309 Not Succession[Codigo - u, Elaborar caso de teste - complete] | | |
# 310 Not Succession[Elaborar caso de teste - begin, Codigo - d] | | |
# 311 Not Succession[Codigo - d, Elaborar caso de teste - complete] | | |
# 312 Not Succession[Elaborar caso de teste - begin, Requisito - c] | | |
# 313 Not Succession[Requisito - c, Elaborar caso de teste - complete] | | |
# 314 Not Succession[Elaborar caso de teste - begin, Requisito - u] | | |
# 315 Not Succession[Requisito - u, Elaborar caso de teste - complete] | | |
# 316 Not Succession[Elaborar caso de teste - begin, Requisito - d] | | |
# 317 Not Succession[Requisito - d, Elaborar caso de teste - complete] | | |
# 318 Not Succession[Elaborar caso de teste - begin, PF - c] | | |
# 319 Not Succession[PF - c, Elaborar caso de teste - complete] | | |
# 320 Not Succession[Elaborar caso de teste - begin, PF - r] | | |
# 321 Not Succession[PF - r, Elaborar caso de teste - complete] | | |
# 322 Not Succession[Elaborar caso de teste - begin, PF - u] | | |
# 323 Not Succession[PF - u, Elaborar caso de teste - complete] | | |
# 324 Not Succession[Elaborar caso de teste - begin, PF - d] | | |
# 325 Not Succession[PF - d, Elaborar caso de teste - complete] | | |
# 326 Precedence[Elaborar caso de teste - begin, Teste - c] | | |
# 327 Precedence[Teste - c, Elaborar caso de teste - complete] | | |
# 328 Precedence[Executar teste - begin, Gestao - u] | | |
# 329 Precedence[Gestao - u, Executar teste - complete] | | |
# 330 Not Succession[Executar teste - begin, Codigo - c] | | |
# 331 Not Succession[Codigo - c, Executar teste - complete] | | |
# 332 Not Succession[Executar teste - begin, Codigo - u] | | |
# 333 Not Succession[Codigo - u, Executar teste - complete] | | |
# 334 Not Succession[Executar teste - begin, Codigo - d] | | |
# 335 Not Succession[Codigo - d, Executar teste - complete] | | |
# 336 Not Succession[Executar teste - begin, Requisito - c] | | |
# 337 Not Succession[Requisito - c, Executar teste - complete] | | |
# 338 Not Succession[Executar teste - begin, Requisito - u] | | |
# 339 Not Succession[Requisito - u, Executar teste - complete] | | |
# 340 Not Succession[Executar teste - begin, Requisito - d] | | |
# 341 Not Succession[Requisito - d, Executar teste - complete] | | |
# 342 Not Succession[Executar teste - begin, PF - c] | | |
# 343 Not Succession[PF - c, Executar teste - complete] | | |
# 344 Not Succession[Executar teste - begin, PF - r] | | |
# 345 Not Succession[PF - r, Executar teste - complete] | | |
# 346 Not Succession[Executar teste - begin, PF - u] | | |
# 347 Not Succession[PF - u, Executar teste - complete] | | |
# 348 Not Succession[Executar teste - begin, PF - d] | | |
# 349 Not Succession[PF - d, Executar teste - complete] | | |
# 350 Not Succession[Executar teste - begin, Teste - c] | | |
# 351 Not Succession[Teste - c, Executar teste - complete] | | |
# 352 Not Succession[Executar teste - begin, Teste - d] | | |
# 353 Not Succession[Teste - d, Executar teste - complete] | | |
# 354 Precedence[Corrigir erro - begin, Gestao - u] | | |
# 355 Precedence[Gestao - u, Corrigir erro - complete] | | |
# 356 Precedence[Corrigir erro - begin, Codigo - u] | | |
# 357 Precedence[Codigo - u, Corrigir erro - complete] | | |
# 358 Not Succession[Corrigir erro - begin, Requisito - c] | | |
# 359 Not Succession[Requisito - c, Corrigir erro - complete] | | |
# 360 Not Succession[Corrigir erro - begin, Requisito - u] | | |
# 361 Not Succession[Requisito - u, Corrigir erro - complete] | | |
# 362 Not Succession[Corrigir erro - begin, Requisito - d] | | |
# 363 Not Succession[Requisito - d, Corrigir erro - complete] | | |
# 364 Not Succession[Corrigir erro - begin, PF - c] | | |
# 365 Not Succession[PF - c, Corrigir erro - complete] | | |
# 366 Not Succession[Corrigir erro - begin, PF - r] | | |
# 367 Not Succession[PF - r, Corrigir erro - complete] | | |
# 368 Not Succession[Corrigir erro - begin, PF - u] | | |
# 369 Not Succession[PF - u, Corrigir erro - complete] | | |
# 370 Not Succession[Corrigir erro - begin, PF - d] | | |
# 371 Not Succession[PF - d, Corrigir erro - complete] | | |
# 372 Not Succession[Corrigir erro - begin, Teste - c] | | |
# 373 Not Succession[Teste - c, Corrigir erro - complete] | | |
# 374 Not Succession[Corrigir erro - begin, Teste - u] | | |
# 375 Not Succession[Teste - u, Corrigir erro - complete] | | |
# 376 Not Succession[Corrigir erro - begin, Teste - d] | | |
# 377 Not Succession[Teste - d, Corrigir erro - complete] | | |
# The checker function for template Not Succession has not been implemented yet.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 MultiperspectiveConformanceAlgorithm('./LogSinteticoProcessoOFICIAL.xes', './LogSinteticoAcessoOFICIAL.xes', './ModeloRecursosOFICIAL.csv', './Modelo_Log_Sintetico_OFICIAL.decl', './ModeloAcessoOFICIAL.csv')
#
# Cell In[23], line 8, in MultiperspectiveConformanceAlgorithm(logProcessoPATH, logAcessoPATH, modeloRecursoPATH, modeloProcessoPATH, modeloAcessoPATH)
#       6 modeloAcessoConvertido = convertModelToRules(modeloAcesso, modeloProcesso)
#       7 convertLogs(logProcesso, logAcesso)
# ----> 8 conformanceProcess = CheckProcessConformance(modeloAcessoConvertido)
#       9 # conformanceAcess = CheckAcessConformance(logProcesso, logAcesso, modeloAcesso)
#      10 conformanceResource = CheckResourceConformance(logProcesso, logAcesso, modeloRecurso)
#
# Cell In[21], line 20, in CheckProcessConformance(modeloProcesso)
#      18     print(idx, constr)
#      19 basic_checker = MPDeclareAnalyzer(log=event_log, declare_model=modeloProcesso, consider_vacuity=False)
# ---> 20 conf_check_res: MPDeclareResultsBrowser = basic_checker.run()
#      21 violacoes = formatViolations(conf_check_res.get_metric(metric="num_violations"))
#      22 return violacoes
#
# File c:\Users\bruni\AppData\Local\Programs\Python\Python312\Lib\site-packages\Declare4Py\ProcessMiningTasks\ConformanceChecking\MPDeclareAnalyzer.py:46, in MPDeclareAnalyzer.run(self)
#      44 log_checkers_results = []
#      45 for trace in self.event_log.get_log():
# ---> 46     log_checkers_results.append(ConstraintChecker().check_trace_conformance(trace, self.process_model,
#      47                                                                             self.consider_vacuity,
#      48                                                                             self.event_log.activity_key))
#      49 return MPDeclareResultsBrowser(log_checkers_results, self.process_model.serialized_constraints)
#
# File c:\Users\bruni\AppData\Local\Programs\Python\Python312\Lib\site-packages\Declare4Py\Utils\Declare\Checkers.py:47, in ConstraintChecker.check_trace_conformance(self, trace, decl_model, consider_vacuity, concept_name)
#      45 rules["time"] = constraint['condition'][-1]  # time condition is always at last position
#      46 try:
# ---> 47     trace_results.append(TemplateConstraintChecker(trace, True, constraint['activities'], rules,
#      48                                                    concept_name).get_template(constraint['template'])())
#      49 except SyntaxError:
#      50     # TODO: use python logger
#      51     if constraint_str not in error_constraint_set:
#
# TypeError: 'NoneType' object is not callable
